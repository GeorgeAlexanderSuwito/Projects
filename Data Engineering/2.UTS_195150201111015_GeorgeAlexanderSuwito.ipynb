# %% [markdown]
# # Extract Transform Load (ETL)
# ----

# %% [markdown]
# ## Extract
# **Mengambil data berasal dari (https://www.themoviedb.org/) menggunakan API dengan format JSON.Terdapat 3 jenis dataset yang saya ambil, yaitu:**
#
# 1.Dataset FILM dengan genre Science Fiction terbaik pada tahun 2018.
#
# https://georgealexandersuwito.github.io/UTS_DataEngineering/df_movie_id_ScienceFiction_2018.json
#
#
# 2.Dataset FILM dengan genre drama terbaik pada tahun 2019.
#
# https://georgealexandersuwito.github.io/UTS_DataEngineering/df_movie_id_drama_2019.json
#
# 3.Dataset FILM dengan genre action terbaik pada tahun 2020.
#
# https://georgealexandersuwito.github.io/UTS_DataEngineering/df_movie_id_action_2020.json

# %% [markdown]
# ### Import Library

# %%
import pandas as pd
import json
import requests
import numpy as np
import ast
import sqlite3 as sq3

# %%
from datetime import datetime
def log(message):
    timestamp_format = '%Y-%h-%d-%H:%M:%S'
    now = datetime.now()
    timestamp = now.strftime(timestamp_format)
    with open("logfile.txt",'a') as f:
        f.write(timestamp+','+message+'\n')

# %%
log("Memulai Proses ETL")

# %%
log("Extract Phase Dimulai")

# %% [markdown]
# ### Mempersiapkan API Key dan Movie API

# %%
api_key  = "YOUR_API"
movie_api = "https://api.themoviedb.org/3/discover/movie?"
basic_url = 'https://api.themoviedb.org/3/movie/{}?{}'

# %%
log("Membuat fungsi find_id dan find_movie untuk Retrieve data API ")

# %%
#fungsi untuk mencari id pada movie dari beberapa page API dengan query
def find_id(page1,page2,q):
    simpan=[]
    for i in range(page1,page2):
        query=f"{q}&page={i}"
        url = movie_api+ api_key+query
       # print(url)
        r = requests.get(url)
        if r.status_code != 200:
            continue
        else:
            data = requests.get(url).json()
            simpan.append(data) 
    df=pd.DataFrame(simpan)
    ar = np.array([])
    ar=np.array([np.append(ar,pd.DataFrame(df['results'][i])['id'].values) for i in range(page1-1,page2-1)])
    ar=ar.flatten()
    return ar

# %%
#fungsi untuk mencari film dari hasil fungsi find_id
def find_movie(movie_id):
    json_list = []
    for movie in movie_id:
        url = basic_url.format(movie, api_key)
        r = requests.get(url)
        if r.status_code != 200:
            continue
        else:
            data = r.json()
            json_list.append(data) 
    return json_list

# %% [markdown]
# #### Retrieve dataset FILM dengan genre Science Fiction terbaik pada tahun 2018.

# %%
log("Retrive dataset FILM dengan genre Science Fiction terbaik pada tahun 2018")

# %%
movie_id_SC_2018 = find_id(1,20,"&with_genres=878&primary_release_year=2018&sort_by=vote_average.desc")

# %%
df_movie_id_SC_2018 = pd.DataFrame(find_movie(movie_id_SC_2018))

# %%
df_movie_id_SC_2018.to_json("df_movie_id_ScienceFiction_2018.json", orient = "records")

# %%
df_movie_id_SC_2018.to_csv("df_movie_id_SC_2018.csv",index=False)

# %% [markdown]
# #### Retrieve dataset FILM dengan genre drama terbaik pada tahun 2019.

# %%
log("Retrieve dataset FILM dengan genre drama terbaik pada tahun 2019")

# %%
movie_id_drama_2019=find_id(1,20,"&with_genres=18&primary_release_year=2019&sort_by=vote_average.desc")

# %%
df_movie_id_drama_2019 = pd.DataFrame(find_movie(movie_id_drama_2019))

# %%
df_movie_id_drama_2019.shape
# Out:
# (380, 25)

# %%
df_movie_id_drama_2019.to_json("df_movie_id_drama_2019.json", orient = "records")

# %%
df_movie_id_drama_2019.to_csv("df_movie_id_drama_2019.csv",index=False)

# %% [markdown]
# #### Retrieve dataset FILM dengan genre action terbaik pada tahun 2020.

# %%
log("Retrieve dataset FILM dengan genre action terbaik pada tahun 2020")

# %%
movie_id_action_2020=find_id(1,20,"&with_genres=28&primary_release_year=2020&sort_by=vote_average.desc")

# %%
df_movie_id_action_2020 = pd.DataFrame(find_movie(movie_id_action_2020))

# %%
df_movie_id_action_2020.shape
# Out:
# (380, 25)

# %%
df_movie_id_action_2020.to_json("df_movie_id_action_2020.json", orient = "records")

# %%
df_movie_id_action_2020.to_csv("df_movie_id_action_2020.csv",index=False)

# %%
log("Extract Phase Selesai")

# %% [markdown]
# ## Transform
# **Membagi dataset menjadi 2 Tabel sebelum melakukan proses Transform**
#
# Tabel pertama: `Dataset FILM dengan genre Science Fiction terbaik pada tahun 2018` digabung dengan
# `Dataset FILM dengan genre drama terbaik pada tahun 2019`
#
# Tabel kedua:`Tabel Dataset FILM dengan genre action terbaik pada tahun 2020`
#
# Task yang akan dikerjakan pada tiap tabel:
#
# 1.Filtering dan Cleaning:Mengecek nilai null dan menyeleksi fitur pada tabel
#
# 2.Deduplication:Mengecek duplikasi data
#
# 3.Format revision:Membenahi format yang sesuai
#
# 4.Key restructuring: Membagi menjadi beberapa tabel

# %% [markdown]
# #### `1.Filtering dan Cleaning`:Mengecek nilai null dan menyeleksi fitur pada tabel

# %% [markdown]
# #### Tabel Pertama:
# Menggabungkan df_movie_id_SC_2018 dengan df_movie_id_drama_2019

# %%
log("Transform Phase Dimulai")

# %%
log("Menggabungkan df_movie_id_SC_2018 dengan df_movie_id_drama_2019 menjadi tabel_1")

# %%
df_movie_id_SC_2018=pd.read_csv('df_movie_id_SC_2018.csv')
df_movie_id_drama_2019=pd.read_csv('df_movie_id_drama_2019csv')

# %%
tabel_1 = pd.concat([df_movie_id_SC_2018,df_movie_id_drama_2019],ignore_index=True)

# %%
#mencari null values(angka)
def null_values(df):
    null_values = df.isnull().sum()
    null_values=null_values[null_values>0].sort_values(ascending=False)
    return null_values

# %%
#mencari null values(percent)
def percent_null_values(df):
    null_values = df.isnull().sum()
    null_values=null_values[null_values>0].sort_values(ascending=False)/len(df)*100
    return null_values

# %%
log("Mengecek null values pada tabel_1")

# %%
null_values(tabel_1)
# Out:
# belongs_to_collection    710
# homepage                 487
# tagline                  484
# backdrop_path            231
# imdb_id                  151
# overview                  45
# runtime                   12
# poster_path                6
# dtype: int64

# %%
percent_null_values(tabel_1)
# Out:
# belongs_to_collection    93.421053
# homepage                 64.078947
# tagline                  63.684211
# backdrop_path            30.394737
# imdb_id                  19.868421
# overview                  5.921053
# runtime                   1.578947
# poster_path               0.789474
# dtype: float64

# %%
log("Melakukan drop column dan rows pada fitur yang banyak null dan kurang informatif pada tabel_1")

# %% [markdown]
# Melakukan Drop Column
#
# column | Alasan
# --- | ---------
# belongs_to_collection | Karena 91% dari keseluruhan data bernilai null
# backdrop_path | fitur tersebut kurang informatif
# imdb_id | karena sudah terdapat id film.
# homepage| kurang informatif karena hanya berisi website film.

# %% [markdown]
# Melakukan Drop Rows
#
# rows | Alasan
# --- | ---------
# runtime | Karena data bernilai null kurang dari 3%
# poster_path|Karena data bernilai null kurang dari 3%

# %%
drop_column=percent_null_values(tabel_1).index[:-3]

# %%
tabel_1=tabel_1.drop(drop_column,axis=1)

# %%
null_values(tabel_1)
# Out:
# overview       45
# runtime        12
# poster_path     6
# dtype: int64

# %%
tabel_1=tabel_1.dropna()

# %%
null_values(tabel_1)
# Out:
# Series([], dtype: int64)

# %% [markdown]
# **Seleksi Fitur pada Tabel 1**

# %%
log("Melakukan seleksi fitur pada tabel_1")

# %%
tabel_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 705 entries, 0 to 759
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   adult                 705 non-null    bool
#  1   budget                705 non-null    int64
#  2   genres                705 non-null    object
#  3   id                    705 non-null    int64
#  4   original_language     705 non-null    object
#  5   original_title        705 non-null    object
#  6   overview              705 non-null    object
#  7   popularity            705 non-null    float64
#  8   poster_path           705 non-null    object
#  9   production_companies  705 non-null    object
#  10  production_countries  705 non-null    object
#  11  release_date          705 non-null    object
#  12  revenue               705 non-null    int64
#  13  runtime               705 non-null    float64
#  14  spoken_languages      705 non-null    object
#  15  status                705 non-null    object
#  16  title                 705 non-null    object
#  17  video                 705 non-null    bool
#  18  vote_average          705 non-null    float64
#  19  vote_count            705 non-null    int64
# dtypes: bool(2), float64(3), int64(4), object(11)
# memory usage: 106.0+ KB

# %% [markdown]
# Melakukan Drop Column
#
# column | Alasan
# --- | ---------
# original_title | Karena sudah ada fitur title
# video | karena kurang informatif (hanya berisi nilai False)
# adult | karena kurang informatif (hanya berisi nilai False)

# %%
tabel_1.adult.value_counts()
# Out:
# False    705
# Name: adult, dtype: int64

# %%
tabel_1.video.value_counts()
# Out:
# False    705
# Name: video, dtype: int64

# %%
tabel_1=tabel_1.drop(['original_title','video','adult'],axis=1)

# %%
tabel_1.shape
# Out:
# (705, 17)

# %%
tabel_1.head(2)
# Out:
#    budget                                             genres      id  \
# 0       0  [{'id': 878, 'name': 'Science Fiction'}, {'id'...  847068
# 1     100  [{'id': 878, 'name': 'Science Fiction'}, {'id'...  807149
#
#   original_language                                           overview  \
# 0                en  A world-class psychiatrist takes on a new pati...
# 1                es  Cuscus's grandfather has the virus, so she is ...
#
#    popularity                       poster_path  \
# 0       0.632  /4V55Aux76qLE0vu66ZpTp7AjWtr.jpg
# 1       0.600  /h2eDPaHiItFid0S1EwVxwRwK2pu.jpg
#
#                                 production_companies production_countries  \
# 0                                                 []                   []
# 1  [{'id': 139032, 'logo_path': None, 'name': 'Ou...                   []
#
#   release_date  revenue  runtime  \
# 0   2018-01-01        0    109.0
# 1   2018-05-20        0     10.0
#
#                                     spoken_languages    status  \
# 0                                                 []  Released
# 1  [{'english_name': 'Spanish', 'iso_639_1': 'es'...  Released
#
#                          title  vote_average  vote_count
# 0  Milgram and the Fastwalkers          10.0           1
# 1                       Cuscus          10.0           1

# %% [markdown]
# #### Tabel Kedua:
# df_movie_id_action_2020

# %%
tabel_2=pd.read_csv('df_movie_id_action_2020.csv')

# %%
log("Mengecek null values pada tabel_2")

# %%
null_values(tabel_2)
# Out:
# belongs_to_collection    340
# homepage                 262
# tagline                  237
# imdb_id                   67
# backdrop_path             58
# overview                  23
# poster_path                6
# dtype: int64

# %%
percent_null_values(tabel_2)
# Out:
# belongs_to_collection    89.473684
# homepage                 68.947368
# tagline                  62.368421
# imdb_id                  17.631579
# backdrop_path            15.263158
# overview                  6.052632
# poster_path               1.578947
# dtype: float64

# %%
log("Melakukan drop column dan rows pada fitur yang banyak null dan kurang informatif pada tabel_2")

# %% [markdown]
# Melakukan Drop Column
#
# column | Alasan
# --- | ---------
# belongs_to_collection | Karena 87% dari keseluruhan data bernilai null
# backdrop_path | karena hanya berisi gambar
# tagline| karena 60% dari keseluruhan data bernilai null
# imdb_id | karena sudah terdapat id film.
# homepage| kurang informatif karena hanya berisi website film.

# %%
tabel_2=tabel_2.drop(['belongs_to_collection','backdrop_path','tagline','imdb_id','homepage'],axis=1)

# %%
tabel_2.shape
# Out:
# (380, 20)

# %% [markdown]
# Melakukan Drop Rows
#
# rows | Alasan
# --- | ---------
# runtime | Karena data bernilai null kurang dari 3%
# poster_path|Karena data bernilai null kurang dari 3%

# %%
tabel_2=tabel_2.dropna()

# %%
null_values(tabel_2)
# Out:
# Series([], dtype: int64)

# %% [markdown]
# **Seleksi Fitur Pada Tabel 2**

# %%
log("Melakukan seleksi fitur pada tabel_2")

# %%
tabel_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 352 entries, 0 to 379
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   adult                 352 non-null    bool
#  1   budget                352 non-null    int64
#  2   genres                352 non-null    object
#  3   id                    352 non-null    int64
#  4   original_language     352 non-null    object
#  5   original_title        352 non-null    object
#  6   overview              352 non-null    object
#  7   popularity            352 non-null    float64
#  8   poster_path           352 non-null    object
#  9   production_companies  352 non-null    object
#  10  production_countries  352 non-null    object
#  11  release_date          352 non-null    object
#  12  revenue               352 non-null    int64
#  13  runtime               352 non-null    int64
#  14  spoken_languages      352 non-null    object
#  15  status                352 non-null    object
#  16  title                 352 non-null    object
#  17  video                 352 non-null    bool
#  18  vote_average          352 non-null    float64
#  19  vote_count            352 non-null    int64
# dtypes: bool(2), float64(2), int64(5), object(11)
# memory usage: 52.9+ KB

# %% [markdown]
# Melakukan Drop Column
#
# column | Alasan
# --- | ---------
# original_title | Karena sudah ada fitur title
# video | karena kurang informatif (hanya berisi nilai False)
# adult | karena kurang informatif (hanya berisi nilai False)

# %%
tabel_2=tabel_2.drop(['original_title','video','adult'],axis=1)

# %%
tabel_2.shape
# Out:
# (352, 17)

# %%
tabel_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 352 entries, 0 to 379
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                352 non-null    int64
#  1   genres                352 non-null    object
#  2   id                    352 non-null    int64
#  3   original_language     352 non-null    object
#  4   overview              352 non-null    object
#  5   popularity            352 non-null    float64
#  6   poster_path           352 non-null    object
#  7   production_companies  352 non-null    object
#  8   production_countries  352 non-null    object
#  9   release_date          352 non-null    object
#  10  revenue               352 non-null    int64
#  11  runtime               352 non-null    int64
#  12  spoken_languages      352 non-null    object
#  13  status                352 non-null    object
#  14  title                 352 non-null    object
#  15  vote_average          352 non-null    float64
#  16  vote_count            352 non-null    int64
# dtypes: float64(2), int64(5), object(10)
# memory usage: 49.5+ KB

# %%
log("Transform Phase Selesai")

# %% [markdown]
# #### `2.Deduplication`:Mengecek duplikasi data

# %%
log("Deduplication Phase Dimulai")

# %% [markdown]
# **Tabel 1**

# %%
log("mengecek adanya duplikasi pada tabel_1")

# %%
tabel_1[tabel_1.duplicated(subset='id')]
# Out:
# Empty DataFrame
# Columns: [budget, genres, id, original_language, overview, popularity, poster_path, production_companies, production_countries, release_date, revenue, runtime, spoken_languages, status, title, vote_average, vote_count]
# Index: []

# %% [markdown]
# **Tabel 2**

# %%
log("mengecek adanya duplikasi pada tabel_2")

# %%
tabel_2[tabel_2.duplicated(subset='id')]
# Out:
# Empty DataFrame
# Columns: [budget, genres, id, original_language, overview, popularity, poster_path, production_companies, production_countries, release_date, revenue, runtime, spoken_languages, status, title, vote_average, vote_count]
# Index: []

# %%
log("Fase Deduplication Selesai")

# %% [markdown]
# #### `3.Format Revision`: Membenahi format yang sesuai

# %%
log("Fase Format Revision Dimulai")

# %% [markdown]
# **Tabel 1**

# %%
tabel_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 705 entries, 0 to 759
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                705 non-null    int64
#  1   genres                705 non-null    object
#  2   id                    705 non-null    int64
#  3   original_language     705 non-null    object
#  4   overview              705 non-null    object
#  5   popularity            705 non-null    float64
#  6   poster_path           705 non-null    object
#  7   production_companies  705 non-null    object
#  8   production_countries  705 non-null    object
#  9   release_date          705 non-null    object
#  10  revenue               705 non-null    int64
#  11  runtime               705 non-null    float64
#  12  spoken_languages      705 non-null    object
#  13  status                705 non-null    object
#  14  title                 705 non-null    object
#  15  vote_average          705 non-null    float64
#  16  vote_count            705 non-null    int64
# dtypes: float64(3), int64(4), object(10)
# memory usage: 99.1+ KB

# %%
log("Melakukan penyesuaian format pada fitur yang bertipe angka di tabel_1")

# %%
tabel_1['budget']=pd.to_numeric(tabel_1['budget'],errors='coerce')

# %%
tabel_1['budget'].value_counts().sort_values(ascending=False)
# Out:
# 0           561
# 50000         7
# 1000          5
# 1000000       5
# 500           4
#            ...
# 150           1
# 6248          1
# 47374         1
# 442000        1
# 55000000      1
# Name: budget, Length: 98, dtype: int64

# %%
tabel_1['budget']=tabel_1['budget'].replace(0,np.nan)

# %%
tabel_1['budget']=tabel_1['budget'].div(1000000)
# Out:
# 0          NaN
# 1       0.0001
# 2          NaN
# 3          NaN
# 4          NaN
#         ...
# 755        NaN
# 756        NaN
# 757    55.0000
# 758     0.0250
# 759        NaN
# Name: budget, Length: 705, dtype: float64

# %%
tabel_1['revenue'].value_counts()
# Out:
# 0             641
# 530243742       1
# 83672673        1
# 290061297       1
# 8100000         1
#              ...
# 24              1
# 43070915        1
# 4973            1
# 956425          1
# 1074251311      1
# Name: revenue, Length: 65, dtype: int64

# %%
tabel_1.revenue = tabel_1.revenue.replace(0, np.nan)
tabel_1.revenue = tabel_1.revenue.div(1000000)

# %%
tabel_1=tabel_1.rename(columns={'budget':'budget_musd','revenue':'revenue_musd'})

# %%
tabel_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 705 entries, 0 to 759
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget_musd           144 non-null    float64
#  1   genres                705 non-null    object
#  2   id                    705 non-null    int64
#  3   original_language     705 non-null    object
#  4   overview              705 non-null    object
#  5   popularity            705 non-null    float64
#  6   poster_path           705 non-null    object
#  7   production_companies  705 non-null    object
#  8   production_countries  705 non-null    object
#  9   release_date          705 non-null    object
#  10  revenue_musd          64 non-null     float64
#  11  runtime               705 non-null    float64
#  12  spoken_languages      705 non-null    object
#  13  status                705 non-null    object
#  14  title                 705 non-null    object
#  15  vote_average          705 non-null    float64
#  16  vote_count            705 non-null    int64
# dtypes: float64(5), int64(2), object(10)
# memory usage: 99.1+ KB

# %%
log("Melakukan penyesuaian format pada fitur yang bertipe waktu di tabel_1")

# %%
tabel_1['release_date']=pd.to_datetime(tabel_1['release_date'])

# %%
tabel_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 705 entries, 0 to 759
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget_musd           144 non-null    float64
#  1   genres                705 non-null    object
#  2   id                    705 non-null    int64
#  3   original_language     705 non-null    object
#  4   overview              705 non-null    object
#  5   popularity            705 non-null    float64
#  6   poster_path           705 non-null    object
#  7   production_companies  705 non-null    object
#  8   production_countries  705 non-null    object
#  9   release_date          705 non-null    datetime64[ns]
#  10  revenue_musd          64 non-null     float64
#  11  runtime               705 non-null    float64
#  12  spoken_languages      705 non-null    object
#  13  status                705 non-null    object
#  14  title                 705 non-null    object
#  15  vote_average          705 non-null    float64
#  16  vote_count            705 non-null    int64
# dtypes: datetime64[ns](1), float64(5), int64(2), object(9)
# memory usage: 99.1+ KB

# %%
log("Melakukan penyesuaian format pada fitur yang bertipe object di tabel_1")

# %%
tabel_1[tabel_1['overview'].str.isspace()]
# Out:
# Empty DataFrame
# Columns: [budget_musd, genres, id, original_language, overview, popularity, poster_path, production_companies, production_countries, release_date, revenue_musd, runtime, spoken_languages, status, title, vote_average, vote_count]
# Index: []

# %%
tabel_1['genres']
# Out:
# 0      [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 1      [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 2      [{'id': 10402, 'name': 'Music'}, {'id': 878, '...
# 3               [{'id': 878, 'name': 'Science Fiction'}]
# 4      [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
#                              ...
# 755    [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 756    [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# 757    [{'id': 80, 'name': 'Crime'}, {'id': 53, 'name...
# 758                        [{'id': 18, 'name': 'Drama'}]
# 759    [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...
# Name: genres, Length: 705, dtype: object

# %%
tabel_1['genres']=tabel_1['genres'].apply(lambda x: ast.literal_eval(x) if isinstance(x,str) else np.nan)

# %%
tabel_1['genres']=tabel_1['genres'].apply(lambda x: "|".join(i['name'] for i in x))

# %%
tabel_1['genres']
# Out:
# 0                 Science Fiction|Drama|Mystery
# 1      Science Fiction|Thriller|Western|Fantasy
# 2                         Music|Science Fiction
# 3                               Science Fiction
# 4                        Horror|Science Fiction
#                          ...
# 755                       Drama|Romance|History
# 756           Drama|History|Romance|Fantasy|War
# 757                        Crime|Thriller|Drama
# 758                                       Drama
# 759                               Romance|Drama
# Name: genres, Length: 705, dtype: object

# %%
tabel_1['production_companies']=tabel_1['production_companies'].apply(lambda x: ast.literal_eval(x))

# %%
tabel_1['production_companies']=tabel_1['production_companies'].apply(lambda x:"|".join(i['name'] for i in x ))

# %%
#tabel_1['production_companies'].apply(lambda x: print(i) for i in x if len(i)>0 )

# %%
tabel_1['production_companies']
# Out:
# 0
# 1                                        Ouroboros Films
# 2          Robert Fox and Jones|Tintoretto Entertainment
# 3                              Grupo Idex|La Boutique 77
# 4                                            Triler Cine
#                              ...
# 755                                          MD Pictures
# 756                                                  PSC
# 757    Warner Bros. Pictures|Joint Effort|Village Roa...
# 758                                   Hohoww Productions
# 759                                                  MTA
# Name: production_companies, Length: 705, dtype: object

# %%
tabel_1['production_countries'] = tabel_1['production_countries'].apply(lambda x: ast.literal_eval(x) if isinstance(x,str) else np.nan )

# %%
tabel_1['production_countries']
# Out:
# 0                                                     []
# 1                                                     []
# 2      [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...
# 3                [{'iso_3166_1': 'ES', 'name': 'Spain'}]
# 4                                                     []
#                              ...
# 755          [{'iso_3166_1': 'ID', 'name': 'Indonesia'}]
# 756              [{'iso_3166_1': 'JP', 'name': 'Japan'}]
# 757    [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...
# 758    [{'iso_3166_1': 'US', 'name': 'United States o...
# 759             [{'iso_3166_1': 'TR', 'name': 'Turkey'}]
# Name: production_countries, Length: 705, dtype: object

# %%
tabel_1['production_countries']=tabel_1['production_countries'].apply(lambda x: "|".join(i['name'] for i in x) )

# %%
tabel_1['production_countries']
# Out:
# 0
# 1
# 2      United Kingdom|United States of America
# 3                                        Spain
# 4
#                         ...
# 755                                  Indonesia
# 756                                      Japan
# 757            Canada|United States of America
# 758                   United States of America
# 759                                     Turkey
# Name: production_countries, Length: 705, dtype: object

# %%
tabel_1['spoken_languages']
# Out:
# 0                                                     []
# 1      [{'english_name': 'Spanish', 'iso_639_1': 'es'...
# 2      [{'english_name': 'English', 'iso_639_1': 'en'...
# 3      [{'english_name': 'English', 'iso_639_1': 'en'...
# 4      [{'english_name': 'Spanish', 'iso_639_1': 'es'...
#                              ...
# 755    [{'english_name': 'Indonesian', 'iso_639_1': '...
# 756    [{'english_name': 'Japanese', 'iso_639_1': 'ja...
# 757    [{'english_name': 'English', 'iso_639_1': 'en'...
# 758    [{'english_name': 'English', 'iso_639_1': 'en'...
# 759    [{'english_name': 'Turkish', 'iso_639_1': 'tr'...
# Name: spoken_languages, Length: 705, dtype: object

# %%
tabel_1['spoken_languages'] = tabel_1['spoken_languages'].apply(lambda x: ast.literal_eval(x) if isinstance(x,str) else np.nan )

# %%
tabel_1['spoken_languages'] = tabel_1['spoken_languages'].apply(lambda x: "|".join(i['name'] for i in x) if isinstance(x,list) else np.nan )

# %%
tabel_1['spoken_languages']
# Out:
# 0
# 1               Español
# 2               English
# 3               English
# 4               Español
#              ...
# 755    Bahasa indonesia
# 756                 日本語
# 757             English
# 758             English
# 759              Türkçe
# Name: spoken_languages, Length: 705, dtype: object

# %%
col_tabel = ["id", "title", "release_date", "genres", 
       "original_language", "budget_musd", "revenue_musd", "production_companies",
       "production_countries", "vote_count", "vote_average", "popularity", "runtime",
       "overview", "spoken_languages", "poster_path"]

# %%
tabel_1=tabel_1.loc[:,col_tabel]

# %%
tabel_1.dropna(thresh = 14, inplace = True)

# %%
tabel_1['production_companies']=tabel_1['production_companies'].replace('',np.nan)

# %%
tabel_1['production_countries']=tabel_1['production_countries'].replace('',np.nan)

# %%
tabel_1['spoken_languages']=tabel_1['spoken_languages'].replace('',np.nan)

# %%
tabel_1['overview'].loc[tabel_1['overview'].str.isspace()]
# Out:
# Series([], Name: overview, dtype: object)

# %%
tabel_1[tabel_1['overview']=='']
# Out:
# Empty DataFrame
# Columns: [id, title, release_date, genres, original_language, budget_musd, revenue_musd, production_companies, production_countries, vote_count, vote_average, popularity, runtime, overview, spoken_languages, poster_path]
# Index: []

# %%
tabel_1[tabel_1['overview']==' ']
# Out:
# Empty DataFrame
# Columns: [id, title, release_date, genres, original_language, budget_musd, revenue_musd, production_companies, production_countries, vote_count, vote_average, popularity, runtime, overview, spoken_languages, poster_path]
# Index: []

# %%
tabel_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 705 entries, 0 to 759
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    705 non-null    int64
#  1   title                 705 non-null    object
#  2   release_date          705 non-null    datetime64[ns]
#  3   genres                705 non-null    object
#  4   original_language     705 non-null    object
#  5   budget_musd           144 non-null    float64
#  6   revenue_musd          64 non-null     float64
#  7   production_companies  485 non-null    object
#  8   production_countries  565 non-null    object
#  9   vote_count            705 non-null    int64
#  10  vote_average          705 non-null    float64
#  11  popularity            705 non-null    float64
#  12  runtime               705 non-null    float64
#  13  overview              705 non-null    object
#  14  spoken_languages      587 non-null    object
#  15  poster_path           705 non-null    object
# dtypes: datetime64[ns](1), float64(5), int64(2), object(8)
# memory usage: 93.6+ KB

# %%
tabel_1.head()
# Out:
#        id                                           title release_date  \
# 0  847068                     Milgram and the Fastwalkers   2018-01-01
# 1  807149                                          Cuscus   2018-05-20
# 2  780614                                         Lazarus   2018-05-02
# 3  767757  IPDENTICAL: Imagine a world without creativity   2018-05-29
# 4  762812                                        Nocturne   2018-11-29
#
#                                      genres original_language  budget_musd  \
# 0             Science Fiction|Drama|Mystery                en          NaN
# 1  Science Fiction|Thriller|Western|Fantasy                es        100.0
# 2                     Music|Science Fiction                en          NaN
# 3                           Science Fiction                en          NaN
# 4                    Horror|Science Fiction                es          NaN
#
#    revenue_musd                           production_companies  \
# 0           NaN                                            NaN
# 1           NaN                                Ouroboros Films
# 2           NaN  Robert Fox and Jones|Tintoretto Entertainment
# 3           NaN                      Grupo Idex|La Boutique 77
# 4           NaN                                    Triler Cine
#
#                       production_countries  vote_count  vote_average  \
# 0                                      NaN           1          10.0
# 1                                      NaN           1          10.0
# 2  United Kingdom|United States of America           1          10.0
# 3                                    Spain           1          10.0
# 4                                      NaN           1          10.0
#
#    popularity  runtime                                           overview  \
# 0       0.632    109.0  A world-class psychiatrist takes on a new pati...
# 1       0.600     10.0  Cuscus's grandfather has the virus, so she is ...
# 2       2.183    110.0  Lazarus is a musical with music and lyrics com...
# 3       0.600      9.0  Anna lives in a retro-futuristic dystopia wher...
# 4       0.600      9.0  When everything seemed to be going normally, a...
#
#   spoken_languages                       poster_path
# 0              NaN  /4V55Aux76qLE0vu66ZpTp7AjWtr.jpg
# 1          Español  /h2eDPaHiItFid0S1EwVxwRwK2pu.jpg
# 2          English  /oMNM5ArncJbLJvyqeHnlJZFGmf2.jpg
# 3          English  /57x22PQ5Nmr91BOiKWgdxAx5Wjp.jpg
# 4          Español  /y3smngJh0IyDj6SjUAntFVC4IxA.jpg

# %%
tabel_1.shape
# Out:
# (705, 16)

# %% [markdown]
# **Tabel 2**

# %%
log("Melakukan penyesuaian format pada fitur yang bertipe angka di tabel_2")

# %%
tabel_2['revenue']=pd.to_numeric(tabel_2['revenue'])

# %%
tabel_2['revenue']=tabel_2['revenue'].div(1000000)

# %%
tabel_2['revenue']=tabel_2['revenue'].replace(0,np.nan)

# %%
tabel_2['budget']=pd.to_numeric(tabel_2['budget'])

# %%
tabel_2['budget']=tabel_2['budget'].div(1000000)

# %%
tabel_2['budget']=tabel_2['budget'].replace(0,np.nan)

# %%
tabel_2=tabel_2.rename(columns={'budget':'budget_musd','revenue':'revenue_musd'})

# %%
col = ['production_companies','production_countries','genres','spoken_languages']

# %%
log("Melakukan penyesuaian format pada fitur yang bertipe object di tabel_2")

# %%
for i in col:
    tabel_2[i]=tabel_2[i].apply(lambda x: ast.literal_eval(x) if isinstance(x,str) else np.nan)
    tabel_2[i]=tabel_2[i].apply(lambda x: "|".join(i['name'] for i in x) if isinstance(x,list) else np.nan)

# %%
tabel_2['production_companies']=tabel_2['production_companies'].replace('',np.nan)

# %%
tabel_2['production_countries']=tabel_2['production_countries'].replace('',np.nan)

# %%
tabel_2['spoken_languages']=tabel_2['spoken_languages'].replace('',np.nan)

# %%
log("Melakukan penyesuaian format pada fitur yang bertipe waktu di tabel_2")

# %%
tabel_2['release_date']=pd.to_datetime(tabel_2['release_date'])

# %%
null_values(tabel_2)
# Out:
# revenue_musd            303
# budget_musd             292
# production_companies     93
# production_countries     45
# spoken_languages         37
# dtype: int64

# %%
tabel_2=tabel_2.loc[:,col_tabel]

# %%
tabel_2=tabel_2.dropna(thresh=14)

# %%
null_values(tabel_2)
# Out:
# revenue_musd            192
# budget_musd             186
# production_companies      4
# production_countries      3
# spoken_languages          1
# dtype: int64

# %%
tabel_2.shape
# Out:
# (241, 16)

# %%
tabel_2.head()
# Out:
#         id                            title release_date  \
# 0   863519                   The Protectors   2020-04-24
# 3   853543                   Assassin's Vow   2020-12-01
# 6   824536  Motu Patlu in the Game of Zones   2020-12-19
# 15  775241             Good Times Bad Times   2020-09-25
# 17  771390                    Macabre Night   2020-12-03
#
#                                                genres original_language  \
# 0                              Science Fiction|Action                en
# 3                                              Action                en
# 6   Animation|Comedy|Mystery|Fantasy|Adventure|Action                hi
# 15                                       Action|Crime                pt
# 17                         Horror|Action|Music|Comedy                pt
#
#     budget_musd  revenue_musd  \
# 0           NaN           NaN
# 3           3.5           NaN
# 6           NaN           NaN
# 15          NaN           NaN
# 17          NaN           NaN
#
#                                  production_companies  \
# 0                Limitbreaker Studios|Skyward Stories
# 3              Pixium Film Group|Safier Entertainment
# 6   Voot Kids|Nickelodeon (IN)|Viacom 18 Motion Pi...
# 15                                              RUGAS
# 17                    Abóbora Filmes|Mina Audiovisual
#
#         production_countries  vote_count  vote_average  popularity  runtime  \
# 0   United States of America           1          10.0       1.201       90
# 3   United States of America           1          10.0       2.503       94
# 6                      India           1          10.0       0.600       87
# 15                  Portugal           2          10.0       0.600        6
# 17                    Brazil           2          10.0       0.840       20
#
#                                              overview     spoken_languages  \
# 0   After finding out the truth about his alien an...              English
# 3   Set in the crime underworld of South Florida, ...              English
# 6   A board game becomes all too real for buddies ...  हिन्दी|தமிழ்|తెలుగు
# 15  The good times we wished we had lived, might h...            Português
# 17  At night, during a transfer, the inmates of a ...            Português
#
#                          poster_path
# 0   /5qs8CrOWBIARlLhsIdueDpT5xiC.jpg
# 3   /c93bJ880nkbaKEP9cush10Nz4fS.jpg
# 6   /xdoQSrB0kzIRT9CWEbMbX2vHYbB.jpg
# 15  /ba4PQ59z7oJ8d5C26rkH1LLqYJc.jpg
# 17  /jJMZjnP26Ih8eeC4oP4RgmY2IFF.jpg

# %%
log("Fase Format Revision Selesai")

# %% [markdown]
# #### `4.Key restructuring`

# %% [markdown]
# **Tabel 1**

# %%
log("Fase Key restructuring Dimulai")

# %%
log("Menggabungkan tabel_1 dengan tabel_2")

# %%
files=['df_movie_id_SC_2018.json','df_movie_id_drama_2019.json','df_movie_id_action_2020.json']

def merge_JsonFiles(filename):
    result = list()
    for f1 in filename:
        with open(f1, 'r') as infile:
            result.extend(json.load(infile))

    with open('Tabel_1.json', 'w') as output_file:
        json.dump(result, output_file)

merge_JsonFiles(files)

# %%
with open('Tabel_1.json') as f:
    data=json.load(f)

# %%
data
# Out:
# [{'adult': False,
#   'backdrop_path': None,
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 878, 'name': 'Science Fiction'},
#    {'id': 18, 'name': 'Drama'},
#    {'id': 9648, 'name': 'Mystery'}],
#   'homepage': '',
#   'id': 847068,
#   'imdb_id': None,
#   'original_language': 'en',
#   'original_title': 'Milgram and the Fastwalkers',
#   'overview': 'A world-class psychiatrist takes on a new patient who is experiencing strange dreams, and is reluctantly drawn into the dark world of aliens and UFOs.',
#   'popularity': 0.6,
#   'poster_path': '/4V55Aux76qLE0vu66ZpTp7AjWtr.jpg',
#   'production_companies': [],
#   'production_countries': [],
#   'release_date': '2018-01-01',
#   'revenue': 0,
#   'runtime': 109.0,
#   'spoken_languages': [],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Milgram and the Fastwalkers',
#   'video': False,
#   'vote_average': 10.0,
#   'vote_count': 1},
#  {'adult': False,
#   'backdrop_path': '/vX5oa5xup7DuUXvckQZgUsxFg9G.jpg',
#   'belongs_to_collection': None,
#   'budget': 100,
#   'genres': [{'id': 878, 'name': 'Science Fiction'},
#    {'id': 53, 'name': 'Thriller'},
#    {'id': 37, 'name': 'Western'},
#    {'id': 14, 'name': 'Fantasy'}],
#   'homepage': 'https://vimeo.com/409409861',
#   'id': 807149,
#   'imdb_id': None,
#   'original_language': 'es',
#   'original_title': 'Cuscus',
#   'overview': "Cuscus's grandfather has the virus, so she is the only one who can get supplies. She must face great challenges as she travels a world devastated by a technological holocaust.",
#   'popularity': 0.6,
#   'poster_path': '/h2eDPaHiItFid0S1EwVxwRwK2pu.jpg',
#   'production_companies': [{'id': 139032,
#     'logo_path': None,
#     'name': 'Ouroboros Films',
#     'origin_country': ''}],
#   'production_countries': [],
#   'release_date': '2018-05-20',
#   'revenue': 0,
#   'runtime': 10.0,
#   'spoken_languages': [{'english_name': 'Spanish',
#     'iso_639_1': 'es',
#     'name': 'Español'}],
#   'status': 'Released',
#   'tagline': 'What is in the Egg? She will know soon.',
#   'title': 'Cuscus',
#   'video': False,
#   'vote_average': 10.0,
#   'vote_count': 1},
#  {'adult': False,
#   'backdrop_path': '/9VjfndliEUZSOfLypOky3tRmrHa.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 10402, 'name': 'Music'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'homepage': 'https://lazarusmusical.com',
#   'id': 780614,
#   'imdb_id': None,
#   'original_language': 'en',
#   'original_title': 'Lazarus',
#   'overview': 'Lazarus is a musical with music and lyrics composed by David Bowie, and a book written by Enda Walsh. First performed at the end of 2015, it was one of the last works Bowie completed before his death on 10 January 2016. The musical is inspired by the 1963 novel The Man Who Fell to Earth by Walter Tevis. Bowie previously starred in the 1976 film adaptation of the same name, directed by Nicolas Roeg.',
#   'popularity': 2.552,
#   'poster_path': '/oMNM5ArncJbLJvyqeHnlJZFGmf2.jpg',
#   'production_companies': [{'id': 146418,
#     'logo_path': None,
#     'name': 'Robert Fox and Jones',
#     'origin_country': ''},
#    {'id': 146419,
#     'logo_path': None,
#     'name': 'Tintoretto Entertainment',
#     'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#    {'iso_3166_1': 'US', 'name': 'United States of America'}],
#   'release_date': '2018-05-02',
#   'revenue': 0,
#   'runtime': 110.0,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': "Look up here, I'm in heaven",
#   'title': 'Lazarus',
#   'video': False,
#   'vote_average': 10.0,
#   'vote_count': 1},
#  {'adult': False,
#   'backdrop_path': None,
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 878, 'name': 'Science Fiction'}],
#   'homepage': 'https://www.ipdentical.com/',
#   'id': 767757,
#   'imdb_id': 'tt8618146',
#   'original_language': 'en',
#   'original_title': 'IPDENTICAL: Imagine a world without creativity',
#   'overview': "Anna lives in a retro-futuristic dystopia where intellectual property doesn't exist: there's no creativity, no R&D, no innovation and no diversity. Tired of the reality surrounding here, she starts the search of the only original song she remembers.",
#   'popularity': 0.84,
#   'poster_path': '/57x22PQ5Nmr91BOiKWgdxAx5Wjp.jpg',
#   'production_companies': [{'id': 148656,
#     'logo_path': None,
#     'name': 'Grupo Idex',
#     'origin_country': ''},
#    {'id': 148657,
#     'logo_path': None,
#     'name': 'La Boutique 77',
#     'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'ES', 'name': 'Spain'}],
#   'release_date': '2018-05-29',
#   'revenue': 0,
#   'runtime': 9.0,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'IPDENTICAL: Imagine a world without creativity',
#   'video': False,
#   'vote_average': 10.0,
#   'vote_count': 1},
#  {'adult': False,
#   'backdrop_path': '/8Lqxmn38rT097KzzCb7KPmcX0en.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 27, 'name': 'Horror'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'homepage': '',
#   'id': 762812,
#   'imdb_id': None,
#   'original_language': 'es',
#   'original_title': 'Nocturno',
#   'overview': 'When everything seemed to be going normally, an event will change the life of a security guard forever.',
#   'popularity': 0.6,
#   'poster_path': '/y3smngJh0IyDj6SjUAntFVC4IxA.jpg',
#   'production_companies': [{'id': 143474,
#     'logo_path': None,
#     'name': 'Triler Cine',
#     'origin_country': ''}],
#   'production_countries': [],
#   'release_date': '2018-11-29',
#   'revenue': 0,
#   'runtime': 9.0,
#   'spoken_languages': [{'english_name': 'Spanish',
#     'iso_639_1': 'es',
#     'name': 'Español'}],
#   'status': 'Released',
#   'tagline': 'Nocturno',
#   'title': 'Nocturne',
#   'video': False,
#   'vote_average': 10.0,
#   'vote_count': 1},
#  {'adult': False,
#   'backdrop_path': None,
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 14, 'name': 'Fantasy'},
#    {'id': 878, 'name': 'Science Fiction'},
#    {'id': 27, 'name': 'Horror'}],
#   'homepage': '',
#   'id': 760576,
#   'imdb_id': None,
#   'original_language': 'es',
#   'original_title': 'El Último Rito',
#   'overview': 'In the distant future, demonic creatures rule the earth. Two magicians try to open a chest that holds the secret of the salvation of humanity.',
#   'popularity': 2.233,
#   'poster_path': '/sk1sXr1pslO7ol1wxrzwnFG95ju.jpg',
#   'production_companies': [{'id': 143029,
#     'logo_path': None,
#     'name': 'Media Botella Films',
#     'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'AR', 'name': 'Argentina'}],
#   'release_date': '2018-12-09',
#   'revenue': 0,
#   'runtime': 4.0,
#   'spoken_languages': [{'english_name': 'Spanish',
#     'iso_639_1': 'es',
#     'name': 'Español'}],
#   'status': 'Released',
#   'tagline': 'A magical post apocalyptic world',
#   'title': 'The Last Rite',
#   'video': False,
#   'vote_average': 10.0,
#   'vote_count': 1},
#  {'adult': False,
#   'backdrop_path': None,
#   'belongs_to_collection': None,
#   'budget': 2000,
#   'genres': [{'id': 878, 'name': 'Science Fiction'},
#    {'id': 53, 'name': 'Thriller'}],
#   'homepage': 'https://thinkspeak.org/my-name-is-art/',
#   'id': 691760,
#   'imdb_id': 'tt8660076',
#   'original_language': 'en',
#   'original_title': 'My Name is Art',
#   'overview': "Everything changes for a young suburbanite when a mysterious stranger appears at his doorstep and asks him a single, simple question: 'What is your name?'",
#   'popularity': 0.6,
#   'poster_path': '/rQl1WCgTtaWBpblMrmBsUWuANct.jpg',
#   'production_companies': [{'id': 131989,
#     'logo_path': None,
#     'name': 'Think Speak Films',
#     'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2018-06-01',
#   'revenue': 0,
#   'runtime': 14.0,
#   'spoken_languages': [],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'My Name is Art',
#   'video': False,
#   'vote_average': 10.0,
#   'vote_count': 1},
#  {'adult': False,
#   'backdrop_path': None,
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 27, 'name': 'Horror'},
#    {'id': 14, 'name': 'Fantasy'},
#    {'id': 9648, 'name': 'Mystery'},
#    {'id': 878, 'name': 'Science Fiction'},
#    {'id': 53, 'name': 'Thriller'}],
#   'homepage': '',
#   'id': 674329,
#   'imdb_id': 'tt7830498',
#   'original_language': 'en',
#   'original_title': "Devil's Night",
#   'overview': 'A group of kids find trouble after messing around with a local urban legend involving a witch on the night before Halloween.',
#   'popularity': 0.6,
#   'poster_path': '/t2L9AHd3G6GIfWqytij41d0wYGH.jpg',
#   'production_companies': [],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2018-06-18',
#   'revenue': 0,
#   'runtime': 10.0,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': "Devil's Night",
#   'title': "Devil's Night",
#   'video': False,
#   'vote_average': 10.0,
#   'vote_count': 1},
#  {'adult': False,
#   'backdrop_path': '/4xotC81YX6m0rgufyQMZH9AvW6F.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 878, 'name': 'Science Fiction'},
#    {'id': 27, 'name': 'Horror'}],
#   'homepage': '',
#   'id': 664442,
#   'imdb_id': 'tt6498220',
#   'original_language': 'en',
#   'original_title': 'Another Plan from Outer Space',
#   'overview': 'Crash landing on Earth after an extended deep space mission, five astronauts find their hope for a rescue quickly turning into a fight for survival.',
#   'popularity': 1.21,
#   'poster_path': '/pO4EiWHwkd7tgRrXhG8XcCUZrPX.jpg',
#   'production_companies': [{'id': 131775,
#     'logo_path': None,
#     'name': 'Bad Amigo Pictures',
#     'origin_country': ''},
#    {'id': 131776,
#     'logo_path': None,
#     'name': 'Polland Pictures',
#     'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2018-09-08',
#   'revenue': 0,
#   'runtime': 0.0,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Another Plan from Outer Space',
#   'video': False,
#   'vote_average': 10.0,
#   'vote_count': 1},
#  {'adult': False,
#   'backdrop_path': '/3EINWvTYMO51uP4espKNqlj13Sg.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 878, 'name': 'Science Fiction'},
#    {'id': 9648, 'name': 'Mystery'}],
#   'homepage': None,
#   'id': 654622,
#   'imdb_id': 'tt7923416',
#   'original_language': 'en',
#   'original_title': 'Lapso',
#   'overview': 'A woman receives mysterious messages from a unexpected stalker.',
#   'popularity': 0.633,
#   'poster_path': '/tdHJeOtpqWdvmuajlbqXGLkjnGD.jpg',
#   'production_companies': [],
#   'production_countries': [],
#   'release_date': '2018-03-05',
#   'revenue': 0,
#   'runtime': 10.0,
#   'spoken_languages': [{'english_name': 'Portuguese',
#     'iso_639_1': 'pt',
#     'name': 'Português'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Lapse',
#   'video': False,
#   'vote_average': 10.0,
#   'vote_count': 1},
#  {'adult': False,
#   'backdrop_path': None,
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 878, 'name': 'Science Fiction'},
#    {'id': 53, 'name': 'Thriller'}],
#   'homepage': 'https://www.metropolpics.com/future-lies',
#   'id': 645674,
#   'imdb_id': 'tt6147874',
#   'original_language': 'en',
#   'original_title': 'Future Lies',
#   'overview': 'A love-crazed couple from the future is chased back in time by the treacherous underworld they betrayed.',
#   'popularity': 0.887,
#   'poster_path': '/vkQKef7W079pRm85ixbAb1xVdLu.jpg',
#   'production_companies': [{'id': 112485,
#     'logo_path': None,
#     'name': 'Metropol Pictures',
#     'origin_country': ''}],
#   'production_countries': [],
#   'release_date': '2018-12-28',
#   'revenue': 0,
#   'runtime': 118.0,
#   'spoken_languages': [],
#   'status': 'Released',
#   'tagline': 'Time will tell.',
#   'title': 'Future Lies',
#   'video': False,
#   'vote_average': 10.0,
#   'vote_count': 1},
#  {'adult': False,
#   'backdrop_path': '/pthlW83pAMJKCiQholi3yrhoB5Z.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 18, 'name': 'Drama'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'homepage': '',
#   'id': 633203,
#   'imdb_id': 'tt7419162',
#   'original_language': 'en',
#   'original_title': 'The Shipment',
#   'overview': 'An ex-slave trader struggles to live a reformed life as a lowly interplanetary cargo hauler. Stranded and broke, he faces his dark past and difficult ethical choices in a desperate attempt to provide a better life for his daughter.',
#   'popularity': 0.727,
#   'poster_path': '/eiHCbnrD3XddLzKYY5kJZymzO4j.jpg',
#   'production_companies': [],
#   'production_countries': [{'iso_3166_1': 'CA', 'name': 'Canada'}],
#   'release_date': '2018-10-21',
#   'revenue': 0,
#   'runtime': 30.0,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': "Honest living isn't always clean",
#   'title': 'The Shipment',
#   'video': False,
#   'vote_average': 10.0,
#   'vote_count': 2},
#  {'adult': False,
#   'backdrop_path': '/32sGcUvj2B8x0uxGaJXeFjcvT8F.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 35, 'name': 'Comedy'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'homepage': '',
#   'id': 547575,
#   'imdb_id': 'tt9301520',
#   'original_language': 'pt',
#   'original_title': 'Tommy Brilho',
#   'overview': 'Despite being invisible, Tommy Brilho has an impeccable style. Will it be enough to get noticed by his crush?',
#   'popularity': 0.6,
#   'poster_path': '/sWzFI0hFtPfrEjYcqEiJ1o6ARvz.jpg',
#   'production_companies': [],
#   'production_countries': [{'iso_3166_1': 'BR', 'name': 'Brazil'}],
#   'release_date': '2018-06-01',
#   'revenue': 0,
#   'runtime': 17.0,
#   'spoken_languages': [{'english_name': 'Portuguese',
#     'iso_639_1': 'pt',
#     'name': 'Português'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Tommy Brilho',
#   'video': False,
#   'vote_average': 10.0,
#   'vote_count': 1},
#  {'adult': False,
#   'backdrop_path': '/mzqFDIWJ9VjFdoVQV1QQYj4cbKJ.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 878, 'name': 'Science Fiction'},
#    {'id': 12, 'name': 'Adventure'}],
#   'homepage': '',
#   'id': 545874,
#   'imdb_id': None,
#   'original_language': 'fr',
#   'original_title': 'Ma vie est un film',
#   'overview': 'During excavations, a paleontologist bumps into a Tyrannosaurus.',
#   'popularity': 0.6,
#   'poster_path': '/bj23SvlG1A2JlJawPPPRvI6K3CS.jpg',
#   'production_companies': [],
#   'production_countries': [{'iso_3166_1': 'FR', 'name': 'France'}],
#   'release_date': '2018-07-01',
#   'revenue': 0,
#   'runtime': 1.0,
#   'spoken_languages': [{'english_name': 'French',
#     'iso_639_1': 'fr',
#     'name': 'Français'}],
#   'status': 'Released',
#   'tagline': 'Beware of the plastic T-Rex',
#   'title': 'My life is a movie',
#   'video': False,
#   'vote_average': 10.0,
#   'vote_count': 1},
#  {'adult': False,
#   'backdrop_path': '/pBegoDTJT48T06mlBfHozXdo4Tk.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 18, 'name': 'Drama'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'homepage': None,
#   'id': 542220,
#   'imdb_id': 'tt8837508',
#   'original_language': 'fr',
#   'original_title': 'Love You Sun',
#   'overview': '',
#   'popularity': 0.6,
#   'poster_path': '/bU2ypHnbQoTInd4hwRmkefTitpT.jpg',
#   'production_companies': [{'id': 107705,
#     'logo_path': None,
#     'name': 'Blue Ghost',
#     'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'FR', 'name': 'France'}],
#   'release_date': '2018-03-02',
#   'revenue': 0,
#   'runtime': None,
#   'spoken_languages': [{'english_name': 'French',
#     'iso_639_1': 'fr',
#     'name': 'Français'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Love You Sun',
#   'video': False,
#   'vote_average': 10.0,
#   'vote_count': 1},
#  {'adult': False,
#   'backdrop_path': None,
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 878, 'name': 'Science Fiction'}],
#   'homepage': None,
#   'id': 542030,
#   'imdb_id': 'tt9485318',
#   'original_language': 'en',
#   'original_title': 'Shahmaran',
#   'overview': 'The seven minute cinematic experience created by director Emmanuel Adjei for artist Sevdaliza explores and questions the fascinations and desires of the human mind, telling the story of the black man, who continues life in a cycle of oppression. The modern chains, of aspiring for success, power and decadence that create a false sense of freedom and autonomy.',
#   'popularity': 0.6,
#   'poster_path': '/1ZRNIs9XeZj2bYMVD47WWwIF7Su.jpg',
#   'production_companies': [{'id': 107652,
#     'logo_path': None,
#     'name': 'COMPULSORY',
#     'origin_country': ''},
#    {'id': 107653, 'logo_path': None, 'name': 'HALAL', 'origin_country': 'NL'},
#    {'id': 107654,
#     'logo_path': None,
#     'name': 'Handsome',
#     'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2018-07-31',
#   'revenue': 0,
#   'runtime': 7.0,
#   'spoken_languages': [],
#   'status': 'Released',
#   'tagline': 'You promised us paradise',
#   'title': 'Shahmaran',
#   'video': False,
#   'vote_average': 10.0,
#   'vote_count': 1},
#  {'adult': False,
#   'backdrop_path': None,
#   'belongs_to_collection': None,
#   'budget': 450,
#   'genres': [{'id': 878, 'name': 'Science Fiction'},
#    {'id': 9648, 'name': 'Mystery'}],
#   'homepage': None,
#   'id': 541204,
#   'imdb_id': None,
#   'original_language': 'en',
#   'original_title': 'Veteran of the Psychic Wars',
#   'overview': 'Pipe Man continues his journey through the mysterious immensity of nature, while at the same time, establishing contact with humans for the first time and discovering a new fascination: the act of killing.',
#   'popularity': 0.633,
#   'poster_path': '/9qhI7GnksHsLtOY8fWB5nvAnEYC.jpg',
#   'production_companies': [{'id': 96253,
#     'logo_path': None,
#     'name': 'Popsec Studio',
#     'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'PT', 'name': 'Portugal'}],
#   'release_date': '2018-05-09',
#   'revenue': 0,
#   'runtime': 14.0,
#   'spoken_languages': [],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Veteran of the Psychic Wars',
#   'video': False,
#   'vote_average': 10.0,
#   'vote_count': 1},
#  {'adult': False,
#   'backdrop_path': '/s4sShZY5AvqDP4LS20QM3jN6Jni.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 99, 'name': 'Documentary'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'homepage': 'https://www.livinguniverse.com.au',
#   'id': 539835,
#   'imdb_id': 'tt5226346',
#   'original_language': 'en',
#   'original_title': 'Living Universe',
#   'overview': "The next great voyage of human exploration has already begun: the search for life on planets orbiting distant stars. With extraordinary CGI, the world's most inspiring scientists, via extreme environments on Earth and around the solar system, the film takes viewers aboard the next generation of space ships, across the cosmos and beneath the clouds of the exo-planets to discover The Living Universe.",
#   'popularity': 0.6,
#   'poster_path': '/uK8l2A65XSWioDrps69ruBrRf8b.jpg',
#   'production_companies': [{'id': 6747,
#     'logo_path': '/uLTkpA3dpMrGwBIDin8OByW39gQ.png',
#     'name': 'Essential Media and Entertainment',
#     'origin_country': 'AU'},
#    {'id': 16888,
#     'logo_path': '/di3Bw89NYi83N769K6wYnqqSFHS.png',
#     'name': 'ZED',
#     'origin_country': 'FR'},
#    {'id': 7584,
#     'logo_path': '/eGkfvvyf4fJTvBUR1xt1669IPA3.png',
#     'name': 'Screen Australia',
#     'origin_country': 'AU'},
#    {'id': 104145,
#     'logo_path': '/pXEmryDYZUOHAeb218RcKQgdJ4t.png',
#     'name': 'Create NSW',
#     'origin_country': 'AU'},
#    {'id': 100886,
#     'logo_path': '/4WZMpUq2FoiRbcHGcfjN8ZklYZr.png',
#     'name': 'MEDIA sub-programme of Creative Europe',
#     'origin_country': 'BE'},
#    {'id': 96320,
#     'logo_path': '/mRs4TJMjhSbeEX893pPA3JDHjsy.png',
#     'name': 'CuriosityStream',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'AU', 'name': 'Australia'},
#    {'iso_3166_1': 'FR', 'name': 'France'}],
#   'release_date': '2018-08-09',
#   'revenue': 0,
#   'runtime': 88.0,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': "It's Time to Meet the Neighbours",
#   'title': 'Living Universe',
#   'video': False,
#   'vote_average': 10.0,
#   'vote_count': 1},
#  {'adult': False,
#   'backdrop_path': None,
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 53, 'name': 'Thriller'},
#    {'id': 878, 'name': 'Science Fiction'},
#    {'id': 9648, 'name': 'Mystery'}],
#   'homepage': '',
#   'id': 533050,
#   'imdb_id': 'tt7842486',
#   'original_language': 'en',
#   'original_title': 'The Chairman',
#   'overview': 'Corporate researchers go behind the back of their mysterious employer to test the telepathic abilities of a traumatized girl and her father.',
#   'popularity': 0.6,
#   'poster_path': '/d3ZDvSpmVOfI3rESnlk6x1Y67E1.jpg',
#   'production_companies': [],
#   'production_countries': [],
#   'release_date': '2018-06-28',
#   'revenue': 0,
#   'runtime': 20.0,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'The Chairman',
#   'video': False,
#   'vote_average': 10.0,
#   'vote_count': 1},
#  {'adult': False,
#   'backdrop_path': None,
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 878, 'name': 'Science Fiction'}],
#   'homepage': None,
#   'id': 530904,
#   'imdb_id': 'tt8695258',
#   'original_language': 'ja',
#   'original_title': 'ami.exe・v.?.?',
#   'overview': 'Ami continues to explore Kabukicho.',
#   'popularity': 0.6,
#   'poster_path': '/yLC2BeJ75W7Jiru4T58y7P335pL.jpg',
#   'production_companies': [],
#   'production_countries': [{'iso_3166_1': 'JP', 'name': 'Japan'}],
#   'release_date': '2018-04-21',
#   'revenue': 0,
#   'runtime': 12.0,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'},
#    {'english_name': 'French', 'iso_639_1': 'fr', 'name': 'Français'},
#    {'english_name': 'Japanese', 'iso_639_1': 'ja', 'name': '日本語'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'ami.exe・v.?.?',
#   'video': False,
#   'vote_average': 10.0,
#   'vote_count': 1},
#  {'adult': False,
#   'backdrop_path': None,
#   'belongs_to_collection': None,
#   'budget': 1537,
#   'genres': [{'id': 18, 'name': 'Drama'},
#    {'id': 53, 'name': 'Thriller'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'homepage': None,
#   'id': 528802,
#   'imdb_id': None,
#   'original_language': 'es',
#   'original_title': 'Estatus',
#   'overview': '',
#   'popularity': 0.6,
#   'poster_path': '/uKtM5iSH6BLItNGNfQNcoW11LIk.jpg',
#   'production_companies': [{'id': 105370,
#     'logo_path': None,
#     'name': 'Samurai Films',
#     'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'ES', 'name': 'Spain'}],
#   'release_date': '2018-01-01',
#   'revenue': 0,
#   'runtime': None,
#   'spoken_languages': [{'english_name': 'Spanish',
#     'iso_639_1': 'es',
#     'name': 'Español'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Estatus',
#   'video': False,
#   'vote_average': 10.0,
#   'vote_count': 1},
#  {'adult': False,
#   'backdrop_path': '/o1eHejv0ghTjdmjYpLyKFu0zUyP.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 35, 'name': 'Comedy'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'homepage': 'https://www.toei.co.jp/release/bb/1212480_971.html',
#   'id': 518135,
#   'imdb_id': None,
#   'original_language': 'ja',
#   'original_title': 'ヒーローママ★リーグ',
#   'overview': 'Nanami, Jasmine and Houka, who once fought to bring peace to the world, are now happily married and with children. However, the evil that threatens humanity is immortal, and now they must face a daily struggle to balance their fight as "heroes" and their duty as "mamas". It is their goal to succeed at that struggle and to keep the world safe, becoming the brightest of "glittering mamas". The three thought of the plan to make it happen whilst at a café, but at the same time, Space Shinobu Demost\'s terrifying plan to invade the Earth moves into action!',
#   'popularity': 1.4,
#   'poster_path': '/csVctzEXInFexV55dQvJE6ToAIM.jpg',
#   'production_companies': [{'id': 5822,
#     'logo_path': '/qyTbRgCyU9NLKvKaiQVbadtr7RY.png',
#     'name': 'Toei Company',
#     'origin_country': 'JP'}],
#   'production_countries': [],
#   'release_date': '2018-05-13',
#   'revenue': 0,
#   'runtime': 16.0,
#   'spoken_languages': [{'english_name': 'Japanese',
#     'iso_639_1': 'ja',
#     'name': '日本語'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Hero Mama ★ League',
#   'video': False,
#   'vote_average': 10.0,
#   'vote_count': 1},
#  {'adult': False,
#   'backdrop_path': None,
#   'belongs_to_collection': None,
#   'budget': 200,
#   'genres': [{'id': 18, 'name': 'Drama'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'homepage': '',
#   'id': 508713,
#   'imdb_id': 'tt7437508',
#   'original_language': 'de',
#   'original_title': 'Juna',
#   'overview': 'A dream shows Juna that she has only one last day to live. Ignorantly she initiated the process itself. The attempt to avert her fate failed. A story about the problem of artificial life.',
#   'popularity': 0.6,
#   'poster_path': '/7aTsGraUWFVijdfHPpHzMrQ1uRR.jpg',
#   'production_companies': [{'id': 130742,
#     'logo_path': None,
#     'name': 'NOT FROM L.A. PRODUTCION BERLIN',
#     'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'DE', 'name': 'Germany'}],
#   'release_date': '2018-03-20',
#   'revenue': 200,
#   'runtime': 12.0,
#   'spoken_languages': [{'english_name': 'German',
#     'iso_639_1': 'de',
#     'name': 'Deutsch'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Juna',
#   'video': False,
#   'vote_average': 10.0,
#   'vote_count': 1},
#  {'adult': False,
#   'backdrop_path': None,
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 878, 'name': 'Science Fiction'}],
#   'homepage': '',
#   'id': 507868,
#   'imdb_id': 'tt4214806',
#   'original_language': 'en',
#   'original_title': 'Stage V',
#   'overview': "When America's fascination with living forever creates a viral outbreak, the Earth's population starts to reduce in stages. After the first four are completed, CHILDREN and TEENS are the only humans left in an apocalyptic world where they must not only fend for themselves against the virus, but against one another.  What would you do if life handed you the key to live forever? When America's fascination with looking young and living forever creates a viral outbreak, the Earth's population starts to reduce in stages. After the first four are completed, CHILDREN and TEENS are the only humans left in an apocalyptic world where they must not only fend for themselves against the virus, but also...each other. This is STAGE V.",
#   'popularity': 0.6,
#   'poster_path': None,
#   'production_companies': [],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2018-02-27',
#   'revenue': 0,
#   'runtime': 0.0,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Stage V',
#   'video': False,
#   'vote_average': 10.0,
#   'vote_count': 1},
#  {'adult': False,
#   'backdrop_path': None,
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 16, 'name': 'Animation'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'homepage': 'https://animetamago.jp/title.php?id=1',
#   'id': 495869,
#   'imdb_id': None,
#   'original_language': 'ja',
#   'original_title': 'TIME DRIVER 僕らが描いた未来',
#   'overview': 'Yuuto Matsubara is a 27-year-old man who works in the sales department of a major toy maker, but he isn\'t able to pursue his dreams, and he feels hollow every day. He\'s even given up on love with his childhood sweetheart Ai. One day a "Time Driver" robot that runs on the power of dreams appears in front of him, and he is forced into the cockpit against his will. Inside is a 12-year-old version of himself.',
#   'popularity': 0.6,
#   'poster_path': '/6FyaPA9n4dOfGfvzXN0Eyp5MlXU.jpg',
#   'production_companies': [],
#   'production_countries': [],
#   'release_date': '2018-03-10',
#   'revenue': 0,
#   'runtime': 24.0,
#   'spoken_languages': [{'english_name': 'Japanese',
#     'iso_639_1': 'ja',
#     'name': '日本語'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'TIME DRIVER: The Future We Drew',
#   'video': False,
#   'vote_average': 10.0,
#   'vote_count': 1},
#  {'adult': False,
#   'backdrop_path': '/o3nEjqMrEdeCpBFdYZ9nPlswZYX.jpg',
#   'belongs_to_collection': None,
#   'budget': 766284,
#   'genres': [{'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'},
#    {'id': 10751, 'name': 'Family'}],
#   'homepage': '',
#   'id': 494107,
#   'imdb_id': 'tt5796882',
#   'original_language': 'uk',
#   'original_title': 'Бобот та енергія Всесвіту',
#   'overview': '12-year-old dreamer Vlad accidentally gets caught in a conflict between two alien forces. Together with an electric transformer box The Bobot, a brave girl and an eccentric scientist he has to save the world from a global catastrophe.',
#   'popularity': 0.672,
#   'poster_path': '/vmsFxZJhK5kZUjBcWpfp5oUWk4h.jpg',
#   'production_companies': [{'id': 104894,
#     'logo_path': None,
#     'name': 'mental dRive studio',
#     'origin_country': 'UA'}],
#   'production_countries': [{'iso_3166_1': 'UA', 'name': 'Ukraine'}],
#   'release_date': '2018-08-30',
#   'revenue': 0,
#   'runtime': 0.0,
#   'spoken_languages': [{'english_name': 'Ukrainian',
#     'iso_639_1': 'uk',
#     'name': 'Український'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'The Bobot',
#   'video': False,
#   'vote_average': 10.0,
#   'vote_count': 1},
#  {'adult': False,
#   'backdrop_path': '/aC7EqUsLZ2QGVPQSMzNvIo7sSUi.jpg',
#   'belongs_to_collection': None,
#   'budget': 30000,
#   'genres': [{'id': 53, 'name': 'Thriller'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'homepage': 'http://brutesanity.com',
#   'id': 453076,
#   'imdb_id': 'tt5014122',
#   'original_language': 'en',
#   'original_title': 'Brute Sanity',
#   'overview': 'An FBI-trained neuropsychologist teams up with a thief to find a reality-altering device while her insane ex-boss unleashes bizarre traps to stop her.',
#   'popularity': 2.116,
#   'poster_path': '/9q1BXz2iPKnXYitPGOn6vHcdVk6.jpg',
#   'production_companies': [{'id': 89160,
#     'logo_path': None,
#     'name': 'Imaginary Danger Productions',
#     'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2018-10-16',
#   'revenue': 0,
#   'runtime': 82.0,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'Lose Your Mind...Win the War',
#   'title': 'Brute Sanity',
#   'video': False,
#   'vote_average': 10.0,
#   'vote_count': 1},
#  {'adult': False,
#   'backdrop_path': '/sW4fRbqFyzfCmyhi9UZHC6Vb6Wl.jpg',
#   'belongs_to_collection': {'id': 803215,
#    'name': 'Kamen Rider (Heisei) Collection',
#    'poster_path': '/miGKDwjqVfxE9aN077ZZicljgFA.jpg',
#    'backdrop_path': '/9SlnOGjR9EOosSy2PQvFcq4v7z7.jpg'},
#   'budget': 0,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'homepage': 'http://www.build-lupin-vs-pato.jp/',
#   'id': 543094,
#   'imdb_id': 'tt8591008',
#   'original_language': 'ja',
#   'original_title': '劇場版 仮面ライダービルド Be The One',
#   'overview': 'After the end of the civil war that tore apart Japan, the new governors of Touto, Hokuto and Seito work together to reunify the country. However, they are actually members of an extraterrestrial race called the "Blood Tribe" (the same species as Evolto), who assumed their government positions as part of a plan to destroy Earth as they have done to Mars and other planets before. Considering Sento Kiryū (Kamen Rider Build) a major threat to their plans, the Blood Tribe manipulates his friends and other civilians into attacking him. With even his close ally Ryūga Banjō (Kamen Rider Cross-Z) now against him, Sento must fight to survive and stop the Blood Tribe\'s plan from succeeding.',
#   'popularity': 1.768,
#   'poster_path': '/i8qAIvjYzzJio4mBf6OXkd3ML8i.jpg',
#   'production_companies': [{'id': 5822,
#     'logo_path': '/qyTbRgCyU9NLKvKaiQVbadtr7RY.png',
#     'name': 'Toei Company',
#     'origin_country': 'JP'},
#    {'id': 8670,
#     'logo_path': None,
#     'name': 'Ishinomori Productions',
#     'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'JP', 'name': 'Japan'}],
#   'release_date': '2018-08-04',
#   'revenue': 92108679,
#   'runtime': 66.0,
#   'spoken_languages': [{'english_name': 'Japanese',
#     'iso_639_1': 'ja',
#     'name': '日本語'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Kamen Rider Build the Movie: Be The One',
#   'video': False,
#   'vote_average': 9.7,
#   'vote_count': 3},
#  {'adult': False,
#   'backdrop_path': None,
#   'belongs_to_collection': None,
#   'budget': 25000,
#   'genres': [{'id': 12, 'name': 'Adventure'},
#    {'id': 18, 'name': 'Drama'},
#    {'id': 14, 'name': 'Fantasy'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'homepage': 'http://www.sprucefilms.com',
#   'id': 487283,
#   'imdb_id': 'tt6801580',
#   'original_language': 'en',
#   'original_title': 'A Wish for Giants',
#   'overview': 'Sophie, a young volunteer, meets her kindred spirit in Roxie, a girl with a life threatening medical condition and a unique wish to meet Bigfoot.',
#   'popularity': 2.359,
#   'poster_path': '/pHvnOqNBrPKGzP8orbm9bRpsecK.jpg',
#   'production_companies': [{'id': 97394,
#     'logo_path': None,
#     'name': 'Spruce Films',
#     'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2018-02-17',
#   'revenue': 0,
#   'runtime': 79.0,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'An impossible wish. A determined volunteer.',
#   'title': 'A Wish for Giants',
#   'video': False,
#   'vote_average': 9.3,
#   'vote_count': 6},
#  {'adult': False,
#   'backdrop_path': '/l6CECa3vc9QwBLCGv2ygbeczBvG.jpg',
#   'belongs_to_collection': {'id': 803215,
#    'name': 'Kamen Rider (Heisei) Collection',
#    'poster_path': '/miGKDwjqVfxE9aN077ZZicljgFA.jpg',
#    'backdrop_path': '/9SlnOGjR9EOosSy2PQvFcq4v7z7.jpg'},
#   'budget': 0,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 18, 'name': 'Drama'},
#    {'id': 27, 'name': 'Horror'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'homepage': '',
#   'id': 573989,
#   'imdb_id': None,
#   'original_language': 'ja',
#   'original_title': '劇場版 仮面ライダーアマゾンズ Season2 輪廻',
#   'overview': 'Reincarnation is the second of two theatrical compilation movies that preceded the release of "Kamen Rider Amazons: The Last Judgement" feature film. Reincarnation compiles the events of Season 2, it\'s been five years since the conclusion of season 1, the existence of the Amazons has become public knowledge, putting Nozama Pharmaceutical out of business. In their place is 4C (Competitive Creatures Control Center), a new government organisation tasked with hunting down and containing the Amazons threat. However, the Amazon Cells have mutated into a strain capable of infecting humans, transforming victims into insane and bloodthirsty monsters.',
#   'popularity': 1.092,
#   'poster_path': '/wvUD7muvQlBwB0Q3NF7rXQ4uP1B.jpg',
#   'production_companies': [{'id': 5822,
#     'logo_path': '/qyTbRgCyU9NLKvKaiQVbadtr7RY.png',
#     'name': 'Toei Company',
#     'origin_country': 'JP'},
#    {'id': 528,
#     'logo_path': '/fO3Aof3lXQclYpBByYC8aneTXwA.png',
#     'name': 'Bandai Visual',
#     'origin_country': 'JP'},
#    {'id': 9300,
#     'logo_path': '/9sSD1XufVCJWAadNiC9Mwu994VD.png',
#     'name': 'TV Asahi',
#     'origin_country': 'JP'},
#    {'id': 104931,
#     'logo_path': '/aNOZx62BIqRT1ji0gWowiNRXZ4o.png',
#     'name': 'Amazon Prime Video',
#     'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'JP', 'name': 'Japan'}],
#   'release_date': '2018-05-12',
#   'revenue': 0,
#   'runtime': 99.0,
#   'spoken_languages': [{'english_name': 'Japanese',
#     'iso_639_1': 'ja',
#     'name': '日本語'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Kamen Rider Amazons Season 2 the Movie: Reincarnation',
#   'video': False,
#   'vote_average': 9.0,
#   'vote_count': 2},
#  {'adult': False,
#   'backdrop_path': '/vyfKWNSPTBsInRKxx2nRbNJNCWu.jpg',
#   'belongs_to_collection': {'id': 803215,
#    'name': 'Kamen Rider (Heisei) Collection',
#    'poster_path': '/miGKDwjqVfxE9aN077ZZicljgFA.jpg',
#    'backdrop_path': '/9SlnOGjR9EOosSy2PQvFcq4v7z7.jpg'},
#   'budget': 0,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 18, 'name': 'Drama'},
#    {'id': 27, 'name': 'Horror'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'homepage': '',
#   'id': 573987,
#   'imdb_id': None,
#   'original_language': 'ja',
#   'original_title': '劇場版 仮面ライダーアマゾンズ Season1 覚醒',
#   'overview': 'Awakening is the first of two theatrical compilation movies that preceded the release of "Kamen Rider Amazons: The Last Judgement" feature film. Awakening compiles the events of Season 1, which follows a mysterious Amazon hunter named Jin Takayama, who transforms into Kamen Rider Amazon Alpha; the heavily-sheltered Haruka Mizusawa, who transforms into Kamen Rider Amazon Omega; and the Nozama Pest Control Service, a small group of mercenaries contracted to hunt down the awakening Amazons.',
#   'popularity': 1.531,
#   'poster_path': '/1ASf9tQlLcs0RE0MaSth3J5bECs.jpg',
#   'production_companies': [{'id': 5822,
#     'logo_path': '/qyTbRgCyU9NLKvKaiQVbadtr7RY.png',
#     'name': 'Toei Company',
#     'origin_country': 'JP'},
#    {'id': 528,
#     'logo_path': '/fO3Aof3lXQclYpBByYC8aneTXwA.png',
#     'name': 'Bandai Visual',
#     'origin_country': 'JP'},
#    {'id': 9300,
#     'logo_path': '/9sSD1XufVCJWAadNiC9Mwu994VD.png',
#     'name': 'TV Asahi',
#     'origin_country': 'JP'},
#    {'id': 104931,
#     'logo_path': '/aNOZx62BIqRT1ji0gWowiNRXZ4o.png',
#     'name': 'Amazon Prime Video',
#     'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'JP', 'name': 'Japan'}],
#   'release_date': '2018-05-05',
#   'revenue': 0,
#   'runtime': 99.0,
#   'spoken_languages': [{'english_name': 'Japanese',
#     'iso_639_1': 'ja',
#     'name': '日本語'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Kamen Rider Amazons Season 1 the Movie: Awakening',
#   'video': False,
#   'vote_average': 9.0,
#   'vote_count': 2},
#  {'adult': False,
#   'backdrop_path': None,
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 878, 'name': 'Science Fiction'},
#    {'id': 18, 'name': 'Drama'}],
#   'homepage': None,
#   'id': 565629,
#   'imdb_id': 'tt8457708',
#   'original_language': 'es',
#   'original_title': 'La eternidad de Paula',
#   'overview': '',
#   'popularity': 0.6,
#   'poster_path': '/xbyaQsXx2zziMNLIP1uJqUM908h.jpg',
#   'production_companies': [{'id': 17123,
#     'logo_path': None,
#     'name': 'Aldea Cine',
#     'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'VE', 'name': 'Venezuela'}],
#   'release_date': '2018-05-09',
#   'revenue': 0,
#   'runtime': None,
#   'spoken_languages': [{'english_name': 'Spanish',
#     'iso_639_1': 'es',
#     'name': 'Español'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'La eternidad de Paula',
#   'video': False,
#   'vote_average': 9.0,
#   'vote_count': 1},
#  {'adult': False,
#   'backdrop_path': '/2Ysonu35qpVNDwPmIxZxy45OJ2z.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 878, 'name': 'Science Fiction'}],
#   'homepage': '',
#   'id': 549936,
#   'imdb_id': 'tt8085482',
#   'original_language': 'en',
#   'original_title': 'CC',
#   'overview': 'An AID (Artificially Intelligent Device) nanny named CC follows her programming to the letter of the code in order to protect her ward’s best interests.',
#   'popularity': 0.6,
#   'poster_path': '/xoYufk1sI29ZLCQ5TT8LFd70al6.jpg',
#   'production_companies': [{'id': 80591,
#     'logo_path': None,
#     'name': 'Crazy8s Film Society',
#     'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'CA', 'name': 'Canada'}],
#   'release_date': '2018-09-22',
#   'revenue': 0,
#   'runtime': 14.0,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'CC',
#   'video': False,
#   'vote_average': 9.0,
#   'vote_count': 2},
#  {'adult': False,
#   'backdrop_path': '/gQixTwzJIj0adYNSflSv5gmPwez.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 10749, 'name': 'Romance'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'homepage': 'https://www.thetasteoflove.gr',
#   'id': 505090,
#   'imdb_id': 'tt8069260',
#   'original_language': 'el',
#   'original_title': 'Η Γεύση της Αγάπης',
#   'overview': 'Aris, a lonely 48-year-old man, lives with a young beautiful girl who anticipates and fulfills all his desires without asking for anything in return, since she is a robot and the year is 2038. ELLi has a perfect human form, the most advanced artificial intelligence, and access to all the data of Aris in the Cloud, acting as the ideal personal assistant. Until its operational system is upgraded with Artificial Emotions - and now, feeling neglected, it demands to learn what love is.',
#   'popularity': 1.123,
#   'poster_path': '/aAxBrZLh5mxXtFRRCekHtZRx997.jpg',
#   'production_companies': [{'id': 83921,
#     'logo_path': None,
#     'name': 'Foss Productions',
#     'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'GR', 'name': 'Greece'}],
#   'release_date': '2018-02-14',
#   'revenue': 0,
#   'runtime': 73.0,
#   'spoken_languages': [{'english_name': 'Greek',
#     'iso_639_1': 'el',
#     'name': 'ελληνικά'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'The Taste of Love',
#   'video': False,
#   'vote_average': 9.0,
#   'vote_count': 3},
#  {'adult': False,
#   'backdrop_path': None,
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 878, 'name': 'Science Fiction'}],
#   'homepage': '',
#   'id': 459687,
#   'imdb_id': 'tt6682182',
#   'original_language': 'pt',
#   'original_title': 'Bio',
#   'overview': 'The film tells the story of a man who was born in 1959 and died in 2070, told by people who knew him and somehow contributed to his trajectory.',
#   'popularity': 1.198,
#   'poster_path': '/tpqwPY6Mammsz6S328xIDNrVfFx.jpg',
#   'production_companies': [{'id': 90934,
#     'logo_path': None,
#     'name': 'Prana Filmes',
#     'origin_country': 'BR'}],
#   'production_countries': [{'iso_3166_1': 'BR', 'name': 'Brazil'}],
#   'release_date': '2018-01-01',
#   'revenue': 0,
#   'runtime': 105.0,
#   'spoken_languages': [{'english_name': 'Portuguese',
#     'iso_639_1': 'pt',
#     'name': 'Português'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Bio',
#   'video': False,
#   'vote_average': 8.5,
#   'vote_count': 2},
#  {'adult': False,
#   'backdrop_path': '/aOft24tnD6IclI6uTbfuTHNNhu9.jpg',
#   'belongs_to_collection': None,
#   'budget': 800000,
#   'genres': [{'id': 10751, 'name': 'Family'},
#    {'id': 35, 'name': 'Comedy'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'homepage': '',
#   'id': 540632,
#   'imdb_id': 'tt8161554',
#   'original_language': 'nl',
#   'original_title': 'De film van Dylan Haegens',
#   'overview': 'Dylan is very successful at running his own lunchroom and YouTube channel. Then IJsbrand comes into his life and copies everything he does. Dylan decides to get to the bottom of this and puts fame and friendship at risk.',
#   'popularity': 1.812,
#   'poster_path': '/elkvu1QG9vyRBDx5MMRnn6G7lh.jpg',
#   'production_companies': [{'id': 44429,
#     'logo_path': '/dpwZUNOvvpiH7UptylG0zV3npFC.png',
#     'name': '2CFilm',
#     'origin_country': 'NL'},
#    {'id': 108147,
#     'logo_path': '/mBHI49PL0a7g5O0AQAzKXDjMfho.png',
#     'name': 'Liever Sociaal',
#     'origin_country': 'NL'}],
#   'production_countries': [{'iso_3166_1': 'NL', 'name': 'Netherlands'}],
#   'release_date': '2018-08-16',
#   'revenue': 0,
#   'runtime': 81.0,
#   'spoken_languages': [{'english_name': 'Dutch',
#     'iso_639_1': 'nl',
#     'name': 'Nederlands'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'De film van Dylan Haegens',
#   'video': False,
#   'vote_average': 8.5,
#   'vote_count': 14},
#  {'adult': False,
#   'backdrop_path': '/6qVF0gnLnbKCgcMfCpCB8GH7B5I.jpg',
#   'belongs_to_collection': {'id': 573436,
#    'name': 'Spider-Man: Spider-Verse Collection',
#    'poster_path': '/eD4bGQNfmqExIAzKdvX5gDHhI2.jpg',
#    'backdrop_path': '/14F6gMaRjzgsN6EEpiwH87R1I00.jpg'},
#   'budget': 90000000,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 16, 'name': 'Animation'},
#    {'id': 878, 'name': 'Science Fiction'},
#    {'id': 35, 'name': 'Comedy'}],
#   'homepage': 'http://www.intothespiderverse.movie',
#   'id': 324857,
#   'imdb_id': 'tt4633694',
#   'original_language': 'en',
#   'original_title': 'Spider-Man: Into the Spider-Verse',
#   'overview': 'Miles Morales is juggling his life between being a high school student and being a spider-man. When Wilson "Kingpin" Fisk uses a super collider, others from across the Spider-Verse are transported to this dimension.',
#   'popularity': 142.534,
#   'poster_path': '/iiZZdoQBEYBv6id8su7ImL0oCbD.jpg',
#   'production_companies': [{'id': 34,
#     'logo_path': '/GagSvqWlyPdkFHMfQ3pNq6ix9P.png',
#     'name': 'Sony Pictures',
#     'origin_country': 'US'},
#    {'id': 5,
#     'logo_path': '/71BqEFAF4V3qjjMPCpLuyJFB9A.png',
#     'name': 'Columbia Pictures',
#     'origin_country': 'US'},
#    {'id': 7505,
#     'logo_path': '/837VMM4wOkODc1idNxGT0KQJlej.png',
#     'name': 'Marvel Entertainment',
#     'origin_country': 'US'},
#    {'id': 31828,
#     'logo_path': None,
#     'name': 'Avi Arad Productions',
#     'origin_country': 'US'},
#    {'id': 77973,
#     'logo_path': None,
#     'name': 'Lord Miller Productions',
#     'origin_country': 'US'},
#    {'id': 84041,
#     'logo_path': '/XmHMPGzdI5c4WGX1YlxU4s2v7T.png',
#     'name': 'Pascal Pictures',
#     'origin_country': 'US'},
#    {'id': 2251,
#     'logo_path': '/6l16UFSkZ1oPpyBYaILgffFZlTc.png',
#     'name': 'Sony Pictures Animation',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2018-12-06',
#   'revenue': 375540831,
#   'runtime': 117.0,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'},
#    {'english_name': 'Spanish', 'iso_639_1': 'es', 'name': 'Español'}],
#   'status': 'Released',
#   'tagline': 'More Than One Wears the Mask',
#   'title': 'Spider-Man: Into the Spider-Verse',
#   'video': False,
#   'vote_average': 8.4,
#   'vote_count': 10046},
#  {'adult': False,
#   'backdrop_path': '/lmZFxXgJE3vgrciwuDib0N8CfQo.jpg',
#   'belongs_to_collection': {'id': 86311,
#    'name': 'The Avengers Collection',
#    'poster_path': '/5k6WG11oWrXipYD8BAkmMJU4Men.jpg',
#    'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'},
#   'budget': 300000000,
#   'genres': [{'id': 12, 'name': 'Adventure'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'homepage': 'https://www.marvel.com/movies/avengers-infinity-war',
#   'id': 299536,
#   'imdb_id': 'tt4154756',
#   'original_language': 'en',
#   'original_title': 'Avengers: Infinity War',
#   'overview': 'As the Avengers and their allies have continued to protect the world from threats too large for any one hero to handle, a new danger has emerged from the cosmic shadows: Thanos. A despot of intergalactic infamy, his goal is to collect all six Infinity Stones, artifacts of unimaginable power, and use them to inflict his twisted will on all of reality. Everything the Avengers have fought for has led up to this moment - the fate of Earth and existence itself has never been more uncertain.',
#   'popularity': 302.949,
#   'poster_path': '/7WsyChQLEftFiDOVTGkv3hFpyyt.jpg',
#   'production_companies': [{'id': 420,
#     'logo_path': '/hUzeosd33nzE5MCNsZxCGEKTXaQ.png',
#     'name': 'Marvel Studios',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2018-04-25',
# ...
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 878, 'name': 'Science Fiction'},
#    {'id': 28, 'name': 'Action'}],
#   'homepage': 'https://www.youtube.com/watch?v=NegUHlzn_qs',
#   'id': 723597,
#   'imdb_id': 'tt9297074',
#   'original_language': 'en',
#   'original_title': 'Gambit: Playing for Keeps',
#   'overview': "Superhero Gambit is invited to play in a high stakes card game. But it turns out his host is an old enemy out for revenge, and the other players all want him dead. To make matters worse, they're holding Rogue hostage to prevent him from using his powers.",
#   'popularity': 0.787,
#   'poster_path': '/9smohyWs8HlWFAR2wo9ZycTJpAr.jpg',
#   'production_companies': [],
#   'production_countries': [],
#   'release_date': '2020-06-26',
#   'revenue': 0,
#   'runtime': 20,
#   'spoken_languages': [],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Gambit: Playing for Keeps',
#   'video': False,
#   'vote_average': 5.0,
#   'vote_count': 1},
#  {'adult': False,
#   'backdrop_path': None,
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 28, 'name': 'Action'}, {'id': 18, 'name': 'Drama'}],
#   'homepage': '',
#   'id': 721653,
#   'imdb_id': 'tt11779668',
#   'original_language': 'pa',
#   'original_title': 'ਜੱਗਾ ਜਗਰਾਵਾਂ ਜੋਗਾ',
#   'overview': 'Karaj and his wife. Her parents have passed away and he does farming on their land. However, her uncle is convinced that he should own the land instead and files a case against Karaj.',
#   'popularity': 0.6,
#   'poster_path': '/2aP5yAnUyqUYogEveNVplvBsqW3.jpg',
#   'production_companies': [],
#   'production_countries': [{'iso_3166_1': 'IN', 'name': 'India'}],
#   'release_date': '2020-02-14',
#   'revenue': 0,
#   'runtime': 116,
#   'spoken_languages': [{'english_name': 'Punjabi',
#     'iso_639_1': 'pa',
#     'name': 'ਪੰਜਾਬੀ'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Jagga Jagravan Joga',
#   'video': False,
#   'vote_average': 5.0,
#   'vote_count': 1},
#  {'adult': False,
#   'backdrop_path': None,
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 28, 'name': 'Action'}, {'id': 35, 'name': 'Comedy'}],
#   'homepage': '',
#   'id': 717161,
#   'imdb_id': None,
#   'original_language': 'ko',
#   'original_title': '깡치 2',
#   'overview': '\'Junsu\' a bumpkin who hates studying, \'Seok-tae\' a bumpkin who hates to go to the army, \'Cheol-woo\' a bumpkin who has nothing to do. The so-called "Righteous Bully" trio decides to go to Seoul with their mother\'s secret money. They arrived in Seoul, filled with dreams of a bumpkin, but on the verge of losing their money in front of their eyes. To make matters worse, they reunite with their senior, \'Man-su\', and gets caught up in an entangling case that becomes out of control. The "Kkangchi" trio from Gyeongsang-do takes over Seoul!',
#   'popularity': 1.277,
#   'poster_path': '/7If21MGbJHnodu5cn2S5vUV7lFz.jpg',
#   'production_companies': [],
#   'production_countries': [{'iso_3166_1': 'KR', 'name': 'South Korea'}],
#   'release_date': '2020-06-18',
#   'revenue': 0,
#   'runtime': 90,
#   'spoken_languages': [{'english_name': 'Korean',
#     'iso_639_1': 'ko',
#     'name': '한국어/조선말'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Kkangchi 2',
#   'video': False,
#   'vote_average': 5.0,
#   'vote_count': 1},
#  {'adult': False,
#   'backdrop_path': '/6J0edDpYsYbIMdHSAVl9NvtAxo4.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'homepage': '',
#   'id': 714687,
#   'imdb_id': None,
#   'original_language': 'zh',
#   'original_title': '天启大爆炸',
#   'overview': 'Based on the mysterious explosions that happened in ancient China, with ingenious ideas to unblock the secret truth that has puzzled the world for the audience. The mysterious organization "Night Walk Division" follows the bizarre mystery and bravely rushes into the "No Phase City", and a game about the lives of the people unfolds.',
#   'popularity': 0.6,
#   'poster_path': '/f9qIEkuv2ZdviLTHsWDTW1SXWlW.jpg',
#   'production_companies': [],
#   'production_countries': [{'iso_3166_1': 'CN', 'name': 'China'},
#    {'iso_3166_1': 'HK', 'name': 'Hong Kong'}],
#   'release_date': '2020-06-12',
#   'revenue': 0,
#   'runtime': 71,
#   'spoken_languages': [{'english_name': 'Mandarin',
#     'iso_639_1': 'zh',
#     'name': '普通话'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'The Big Explosion',
#   'video': False,
#   'vote_average': 5.0,
#   'vote_count': 1},
#  {'adult': False,
#   'backdrop_path': '/tWxCVe4rQZa3BvR3tMT3t74oVTT.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'homepage': '',
#   'id': 713825,
#   'imdb_id': 'tt12416066',
#   'original_language': 'en',
#   'original_title': 'Robot Riot',
#   'overview': 'Unconscious soldiers are dropped into a testing site only to discover their memories have been wiped and that once docile machines are the new intelligence.',
#   'popularity': 4.778,
#   'poster_path': '/pXv4qbWyj6ycMaWkK2LzlizZQjf.jpg',
#   'production_companies': [],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2020-12-23',
#   'revenue': 0,
#   'runtime': 79,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'The battle has begun.',
#   'title': 'Robot Riot',
#   'video': False,
#   'vote_average': 5.0,
#   'vote_count': 27},
#  {'adult': False,
#   'backdrop_path': '/bJQmlP3UwrsHMXI0BltaO9ziMse.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 28, 'name': 'Action'}, {'id': 80, 'name': 'Crime'}],
#   'homepage': '',
#   'id': 709925,
#   'imdb_id': None,
#   'original_language': 'ko',
#   'original_title': '범죄해결 특수반',
#   'overview': 'There is an unprecedented “Special Squad”, commissioned to solve the unsolved incidents that even the police can’t handle.  Those who have raided the underage prostitution case will be commissioned to investigate the ‘Algo Mall’ mission.  What they’ve thought to be just one of the usual cases of underaged labor, there seem to be a huge background at the end of the dark underworld…  Here comes the crazy ones who beat the bad guys!',
#   'popularity': 1.155,
#   'poster_path': '/l8RRUbFC13Sj5zWA1nugHmdZNcy.jpg',
#   'production_companies': [],
#   'production_countries': [{'iso_3166_1': 'KR', 'name': 'South Korea'}],
#   'release_date': '2020-05-28',
#   'revenue': 0,
#   'runtime': 81,
#   'spoken_languages': [{'english_name': 'Korean',
#     'iso_639_1': 'ko',
#     'name': '한국어/조선말'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Crime Solving Special Squad',
#   'video': False,
#   'vote_average': 5.0,
#   'vote_count': 1},
#  {'adult': False,
#   'backdrop_path': '/iWptWHazDCXqEet7gBhZYyL2rTz.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 80, 'name': 'Crime'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 18, 'name': 'Drama'}],
#   'homepage': '',
#   'id': 706750,
#   'imdb_id': None,
#   'original_language': 'ko',
#   'original_title': '범털',
#   'overview': 'Man-hee, imprisoned for being caught up in an accidental violent case, will be admitted to a violent room where the king of prison can be found. On the other hand, with Tae-soo, the opposition leader being admitted to the same prison, a group of people who are unhappy with the king gather one by one, and the gang members face a desperate crisis.',
#   'popularity': 0.74,
#   'poster_path': '/3Xeqwws1f3QUTsNiJEMsTSTeGbD.jpg',
#   'production_companies': [],
#   'production_countries': [{'iso_3166_1': 'KR', 'name': 'South Korea'}],
#   'release_date': '2020-05-14',
#   'revenue': 0,
#   'runtime': 108,
#   'spoken_languages': [{'english_name': 'Korean',
#     'iso_639_1': 'ko',
#     'name': '한국어/조선말'}],
#   'status': 'Released',
#   'tagline': 'The king of the prison who rules the wild and despicable!',
#   'title': 'King of Prison',
#   'video': False,
#   'vote_average': 5.0,
#   'vote_count': 1},
#  {'adult': False,
#   'backdrop_path': '/9e6OvVX3UNIuqnOjc9xgvMttDHD.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 28, 'name': 'Action'}, {'id': 35, 'name': 'Comedy'}],
#   'homepage': '',
#   'id': 678957,
#   'imdb_id': None,
#   'original_language': 'pt',
#   'original_title': 'Virando a Mesa',
#   'overview': '',
#   'popularity': 0.746,
#   'poster_path': '/pLsChLT7tuB96kBP7LrgIVz0O8T.jpg',
#   'production_companies': [{'id': 53105,
#     'logo_path': '/rn9sEaA8cXurMyd8HnWkhv8KLqi.png',
#     'name': 'Paris Filmes',
#     'origin_country': 'BR'},
#    {'id': 5591,
#     'logo_path': '/27dkBmalsJMmz8VPeukvoOFuYCF.png',
#     'name': 'Downtown Filmes',
#     'origin_country': 'BR'}],
#   'production_countries': [{'iso_3166_1': 'BR', 'name': 'Brazil'}],
#   'release_date': '2020-08-20',
#   'revenue': 0,
#   'runtime': 0,
#   'spoken_languages': [{'english_name': 'Portuguese',
#     'iso_639_1': 'pt',
#     'name': 'Português'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Virando a Mesa',
#   'video': False,
#   'vote_average': 5.0,
#   'vote_count': 2},
#  {'adult': False,
#   'backdrop_path': '/1st8ViUGXwusef2YLk9KA5eHG6j.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 28, 'name': 'Action'}, {'id': 18, 'name': 'Drama'}],
#   'homepage': '',
#   'id': 678480,
#   'imdb_id': 'tt11307492',
#   'original_language': 'es',
#   'original_title': 'Denzura',
#   'overview': "Chad is a fighter who seeks to be the best without losing his principles. In the search for his dream, he meets Vincent, a millionaire businessman who tries to fix Chad's fights so that he loses.",
#   'popularity': 0.6,
#   'poster_path': '/4elcP84znSELMzkT05oWEhil9bi.jpg',
#   'production_companies': [{'id': 143267,
#     'logo_path': None,
#     'name': 'Unexpected Films',
#     'origin_country': 'FR'}],
#   'production_countries': [{'iso_3166_1': 'MX', 'name': 'Mexico'}],
#   'release_date': '2020-11-06',
#   'revenue': 0,
#   'runtime': 65,
#   'spoken_languages': [{'english_name': 'Spanish',
#     'iso_639_1': 'es',
#     'name': 'Español'}],
#   'status': 'Released',
#   'tagline': 'Dying is easy, but living with pain and regret is a constant hell',
#   'title': 'Denzity',
#   'video': False,
#   'vote_average': 5.0,
#   'vote_count': 2},
#  {'adult': False,
#   'backdrop_path': '/qAtSOYOv95lrOXMJFWpRTNzKXES.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 53, 'name': 'Thriller'}],
#   'homepage': '',
#   'id': 673383,
#   'imdb_id': 'tt11470290',
#   'original_language': 'kn',
#   'original_title': 'ಜೆಂಟಲ್ ಮನ್',
#   'overview': 'The film follows the story of a man suffering from a rare disorder called the Sleeping Beauty Syndrome (aka Kleine-Levin syndrome), which leads to excessive sleepiness and leaves him awake for less than five hours a day.',
#   'popularity': 1.439,
#   'poster_path': '/mzTwCl5AgWclaQ4H0h7tyFiAooD.jpg',
#   'production_companies': [{'id': 129203,
#     'logo_path': None,
#     'name': 'G Cinemas Guru Deshpande',
#     'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'IN', 'name': 'India'}],
#   'release_date': '2020-02-07',
#   'revenue': 0,
#   'runtime': 144,
#   'spoken_languages': [{'english_name': 'Kannada',
#     'iso_639_1': 'kn',
#     'name': '?????'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Gentleman',
#   'video': False,
#   'vote_average': 5.0,
#   'vote_count': 1},
#  {'adult': False,
#   'backdrop_path': '/nV7p8pJtpr5fpugqPwSIkEUoDiI.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 12, 'name': 'Adventure'},
#    {'id': 14, 'name': 'Fantasy'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 53, 'name': 'Thriller'}],
#   'homepage': '',
#   'id': 669748,
#   'imdb_id': 'tt12598910',
#   'original_language': 'zh',
#   'original_title': '巨鳄岛',
#   'overview': "The surrounding areas of the Devil's Sea is also known as the Bermuda Triangle of Asia. Due to electromagnetic interference, aviation accidents are common in the region. Lin Hao (Gallen Lo) and his daughter Yi (Liao Yinyue) are passengers of Flight GZ261. As it flies over the Devil's Sea, the plane malfunctions, causing an emergency landing on a crocodile island. Hao and other driving passengers encounter enormous sized crocodiles and spiders and engages in a battle for survival. When Yi is captured by the giant beasts, Hao fights for his life to rescue her daughter.",
#   'popularity': 1.122,
#   'poster_path': '/uVKtTsjOS1WjSpTbTcfVrnmfzyj.jpg',
#   'production_companies': [{'id': 10338,
#     'logo_path': '/el2ap6lvjcEDdbyJoB3oKiYgXu9.png',
#     'name': 'Perfect World Pictures',
#     'origin_country': 'CN'}],
#   'production_countries': [{'iso_3166_1': 'CN', 'name': 'China'}],
#   'release_date': '2020-02-04',
#   'revenue': 0,
#   'runtime': 86,
#   'spoken_languages': [{'english_name': 'Mandarin',
#     'iso_639_1': 'zh',
#     'name': '普通话'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Crocodile Island',
#   'video': False,
#   'vote_average': 5.0,
#   'vote_count': 4},
#  {'adult': False,
#   'backdrop_path': '/17jUBCxqVXXTpNuWJJTTqAvrVnl.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 10752, 'name': 'War'},
#    {'id': 80, 'name': 'Crime'}],
#   'homepage': '',
#   'id': 668574,
#   'imdb_id': 'tt9408568',
#   'original_language': 'zh',
#   'original_title': '捍战',
#   'overview': '',
#   'popularity': 2.02,
#   'poster_path': '/oB8SUdX4tHiP4le3AXNXMPbq9KY.jpg',
#   'production_companies': [],
#   'production_countries': [{'iso_3166_1': 'CN', 'name': 'China'}],
#   'release_date': '2020-02-01',
#   'revenue': 0,
#   'runtime': 90,
#   'spoken_languages': [{'english_name': 'Mandarin',
#     'iso_639_1': 'zh',
#     'name': '普通话'},
#    {'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Battle of Defense',
#   'video': False,
#   'vote_average': 5.0,
#   'vote_count': 1},
#  {'adult': False,
#   'backdrop_path': None,
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 10752, 'name': 'War'},
#    {'id': 35, 'name': 'Comedy'}],
#   'homepage': 'http://nochancemovie.com/',
#   'id': 493550,
#   'imdb_id': 'tt4379420',
#   'original_language': 'en',
#   'original_title': 'No Chance',
#   'overview': "When a group of international criminals from his past kidnap his daughter, the world's greatest commando sets out for revenge in this action-packed parody of everything you loved about the '80s.",
#   'popularity': 1.031,
#   'poster_path': '/b9cZgtzcG2QbttylSWMJCdHU0NK.jpg',
#   'production_companies': [],
#   'production_countries': [],
#   'release_date': '2020-02-18',
#   'revenue': 0,
#   'runtime': 95,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'No Chance',
#   'video': False,
#   'vote_average': 5.0,
#   'vote_count': 3},
#  {'adult': False,
#   'backdrop_path': '/3kDL6wsIAk8IdyNg0QoQtwSjeI3.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 35, 'name': 'Comedy'}],
#   'homepage': '',
#   'id': 663255,
#   'imdb_id': 'tt7369550',
#   'original_language': 'en',
#   'original_title': 'Spy Intervention',
#   'overview': "When the world's greatest spy meets the woman of his dreams, he abandons his adventurous existence and settles into the security of suburbia.",
#   'popularity': 5.938,
#   'poster_path': '/39iRgghrypeIwFVRC2DQjesBkDO.jpg',
#   'production_companies': [{'id': 92336,
#     'logo_path': '/6Xc60wER3i1DfIBzIK1Ot7aI0EC.png',
#     'name': 'Sprockefeller Pictures',
#     'origin_country': 'US'},
#    {'id': 80626,
#     'logo_path': None,
#     'name': 'El Ride Productions',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2020-02-14',
#   'revenue': 0,
#   'runtime': 93,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Spy Intervention',
#   'video': False,
#   'vote_average': 4.9,
#   'vote_count': 17}]

# %%
Tabel_1 = pd.json_normalize(data, sep = "_")

# %%
Tabel_1=Tabel_1.sort_values('revenue',ascending=False)

# %%
log("Key restructing tabel movies")

# %%
movies = Tabel_1[["id", "title", "revenue", "budget", "belongs_to_collection_name", "release_date"]].copy()

# %%
movies.head()
# Out:
#          id                           title     revenue     budget  \
# 37   299536          Avengers: Infinity War  2046239637  300000000
# 67   284054                   Black Panther  1346739107  200000000
# 142  351286  Jurassic World: Fallen Kingdom  1303459585  170000000
# 597  475557                           Joker  1074251311   55000000
# 125  335983                           Venom   855013954  116000000
#
#     belongs_to_collection_name release_date
# 37     The Avengers Collection   2018-04-25
# 67    Black Panther Collection   2018-02-13
# 142   Jurassic Park Collection   2018-06-06
# 597                        NaN   2019-10-02
# 125           Venom Collection   2018-09-28

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 600 entries, 37 to 599
# Data columns (total 6 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          600 non-null    int64
#  1   title                       600 non-null    object
#  2   revenue                     600 non-null    int64
#  3   budget                      600 non-null    int64
#  4   belongs_to_collection_name  41 non-null     object
#  5   release_date                600 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 32.8+ KB

# %%
movies['release_date']=pd.to_datetime(movies['release_date'])

# %%
movies['revenue'] = df.revenue/1000000
movies['budget'] = df.budget/1000000

# %%
movies.head()
# Out:
#          id                           title      revenue  budget  \
# 37   299536          Avengers: Infinity War  2046.239637   300.0
# 67   284054                   Black Panther  1346.739107   200.0
# 142  351286  Jurassic World: Fallen Kingdom  1303.459585   170.0
# 597  475557                           Joker  1074.251311    55.0
# 125  335983                           Venom   855.013954   116.0
#
#     belongs_to_collection_name release_date
# 37     The Avengers Collection   2018-04-25
# 67    Black Panther Collection   2018-02-13
# 142   Jurassic Park Collection   2018-06-06
# 597                        NaN   2019-10-02
# 125           Venom Collection   2018-09-28

# %%
log("Key restructing tabel votes")

# %%
votes = df[['id','vote_count','vote_average']].copy()
votes
# Out:
#          id  vote_count  vote_average
# 0    847068           1          10.0
# 1    807149           1          10.0
# 2    780614           1          10.0
# 3    767757           1          10.0
# 4    762812           1          10.0
# ..      ...         ...           ...
# 595  611369           5           8.2
# 596  616538          11           8.2
# 597  475557       18868           8.2
# 598  730980           3           8.2
# 599  636553           6           8.2
#
# [600 rows x 3 columns]

# %%
log("Key restructing tabel genres")

# %%
genres=pd.json_normalize(data,record_path='genres',meta='id',record_prefix='genre_')
genres
# Out:
#       genre_id       genre_name      id
# 0          878  Science Fiction  847068
# 1           18            Drama  847068
# 2         9648          Mystery  847068
# 3          878  Science Fiction  807149
# 4           53         Thriller  807149
# ...        ...              ...     ...
# 2373     10752              War  493550
# 2374        35           Comedy  493550
# 2375        28           Action  663255
# 2376        12        Adventure  663255
# 2377        35           Comedy  663255
#
# [2378 rows x 3 columns]

# %%
log("Key restructing tabel prod")

# %%
prod=pd.json_normalize(data,record_path='production_companies',meta='id',record_prefix='comp_')
prod.head()
# Out:
#    comp_id comp_logo_path                 comp_name comp_origin_country  \
# 0   139032           None           Ouroboros Films
# 1   146418           None      Robert Fox and Jones
# 2   146419           None  Tintoretto Entertainment
# 3   148656           None                Grupo Idex
# 4   148657           None            La Boutique 77
#
#        id
# 0  807149
# 1  780614
# 2  780614
# 3  767757
# 4  767757

# %%
prod=prod.drop_duplicates(subset='comp_id')

# %%
prod[prod.duplicated()]
# Out:
# Empty DataFrame
# Columns: [comp_id, comp_logo_path, comp_name, comp_origin_country, id]
# Index: []

# %%
prod.head()
# Out:
#    comp_id comp_logo_path                 comp_name comp_origin_country  \
# 0   139032           None           Ouroboros Films
# 1   146418           None      Robert Fox and Jones
# 2   146419           None  Tintoretto Entertainment
# 3   148656           None                Grupo Idex
# 4   148657           None            La Boutique 77
#
#        id
# 0  807149
# 1  780614
# 2  780614
# 3  767757
# 4  767757

# %%
log("Fase Key restructuring Selesai")

# %% [markdown]
# ## Load

# %%
log("Load Phase Dimulai")

# %% [markdown]
# **Tabel 1**

# %%
log("Membuat koneksi database")

# %%
con = sq3.connect("movies_database.db")

# %%
log("Meload tabel ke dalam database")

# %%
movies.to_sql("Movies", con, index = False)

# %%
votes.to_sql("Votes", con, index = False)

# %%
genres.to_sql("Genres", con, index = False)

# %%
prod.to_sql("Prod", con, index = False)

# %%
con.execute("Select * FROM sqlite_master").fetchall()
# Out:
# [('table',
#   'Movies',
#   'Movies',
#   2,
#   'CREATE TABLE "Movies" (\n"id" INTEGER,\n  "title" TEXT,\n  "revenue" REAL,\n  "budget" REAL,\n  "belongs_to_collection_name" TEXT,\n  "release_date" TIMESTAMP\n)'),
#  ('table',
#   'Votes',
#   'Votes',
#   17,
#   'CREATE TABLE "Votes" (\n"id" INTEGER,\n  "vote_count" INTEGER,\n  "vote_average" REAL\n)'),
#  ('table',
#   'Genres',
#   'Genres',
#   21,
#   'CREATE TABLE "Genres" (\n"genre_id" INTEGER,\n  "genre_name" TEXT,\n  "id" INTEGER\n)'),
#  ('table',
#   'Prod',
#   'Prod',
#   34,
#   'CREATE TABLE "Prod" (\n"comp_id" INTEGER,\n  "comp_logo_path" TEXT,\n  "comp_name" TEXT,\n  "comp_origin_country" TEXT,\n  "id" INTEGER\n)')]

# %%
con.execute("SELECT name FROM sqlite_master WHERE type='table' ORDER BY name").fetchall()
# Out:
# [('Genres',), ('Movies',), ('Prod',), ('Votes',)]

# %%
con.close()

# %%
log("Load Phase Selesai")

# %% [markdown]
# ## Proses Query berada pada file "SQL_Query_195150201111015"
#
# ----
# ----
